# %%
# !pip -q install beautifulsoup4 lxml readability-lxml tldextract pdfplumber python-dateutil rank-bm25
import os, json, pathlib
root = pathlib.Path("/content/rag-pgh")
for p in ["data/raw", "data/corpus", "data/test", "data/train", "scripts"]:
    (root/p).mkdir(parents=True, exist_ok=True)

print("Project root:", root)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 139.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 62.0 MB/s eta 0:00:00
# Project root: /content/rag-pgh

# %%
seeds = """
https://en.wikipedia.org/wiki/Pittsburgh
https://en.wikipedia.org/wiki/History_of_Pittsburgh
https://www.visitpittsburgh.com/
https://pittsburghpa.gov/
https://pittsburghpa.gov/finance/tax-guides
https://pittsburghpa.gov/omb/operating-budget
https://www.cmu.edu/
https://www.cmu.edu/events/
https://pittsburghsymphony.org/
https://trustarts.org/
https://www.heinzhistorycenter.org/
https://carnegiemuseums.org/
https://www.thefrickpittsburgh.org/
https://downtownpittsburgh.com/events/
https://www.pittsburghcitypaper.com/pittsburgh/Events
https://www.picklesburgh.com/
https://www.pghrestaurantweek.com/
https://www.pghtacofest.com/
https://littleitalydays.com/
https://www.mlb.com/pirates
https://www.steelers.com/
https://www.nhl.com/penguins
""".strip()

(root/"seeds.txt").write_text(seeds, encoding="utf-8")
print((root/"seeds.txt").read_text()[:500])
# Out:
# https://en.wikipedia.org/wiki/Pittsburgh
# https://en.wikipedia.org/wiki/History_of_Pittsburgh
# https://www.visitpittsburgh.com/
# https://pittsburghpa.gov/
# https://pittsburghpa.gov/finance/tax-guides
# https://pittsburghpa.gov/omb/operating-budget
# https://www.cmu.edu/
# https://www.cmu.edu/events/
# https://pittsburghsymphony.org/
# https://trustarts.org/
# https://www.heinzhistorycenter.org/
# https://carnegiemuseums.org/
# https://www.thefrickpittsburgh.org/
# https://downtownpittsburgh.com/events/
# https://www.pi

# %%
import time, re, hashlib, queue, urllib.parse, urllib.robotparser
import requests
import tldextract
from bs4 import BeautifulSoup

RAW_DIR = root/"data/raw"
URLMAP_PATH = root/"data/raw/url_map.json"
USER_AGENT = "pgh-rag-bot/0.1 (coursework; contact: you@example.com)"
TIMEOUT = 15
SLEEP = 1.0
MAX_PAGES = 800

def normalize_url(u: str) -> str:
    u = urllib.parse.urldefrag(u)[0]
    p = urllib.parse.urlparse(u)
    qs = urllib.parse.parse_qsl(p.query, keep_blank_values=False)
    qs = [(k,v) for (k,v) in qs if not k.lower().startswith(("utm_", "fbclid", "gclid"))]
    new_q = urllib.parse.urlencode(qs)
    return urllib.parse.urlunparse(p._replace(query=new_q))

def same_registered_domain(u: str, allowed_domains: list[str]) -> bool:
    host = urllib.parse.urlparse(u).netloc
    reg = tldextract.extract(host).registered_domain
    return any(reg == d or host.endswith("."+d) for d in allowed_domains)

def load_seeds(path):
    s = pathlib.Path(path).read_text().splitlines()
    seeds = [normalize_url(x.strip()) for x in s if x.strip()]
    allowed = set()
    for u in seeds:
        host = urllib.parse.urlparse(u).netloc
        allowed.add(tldextract.extract(host).registered_domain)
    return seeds, sorted(allowed)

def is_pdf(url: str) -> bool:
    return url.lower().split("?")[0].endswith(".pdf")

def safe_name(url: str) -> str:
    h = hashlib.sha1(url.encode("utf-8")).hexdigest()[:16]
    return f"{h}.pdf" if is_pdf(url) else f"{h}.html"

def fetch(url: str):
    headers = {"User-Agent": USER_AGENT}
    r = requests.get(url, headers=headers, timeout=TIMEOUT)
    r.raise_for_status()
    return r

def extract_links(html: str, base_url: str) -> set[str]:
    soup = BeautifulSoup(html, "lxml")
    out = set()
    for a in soup.find_all("a", href=True):
        href = urllib.parse.urljoin(base_url, a["href"])
        if href.startswith(("mailto:", "javascript:")):
            continue
        out.add(normalize_url(href))
    return out

def crawl():
    seeds, allowed = load_seeds(root/"seeds.txt")
    print("Allowed domains:", allowed)

    robot_cache = {}
    def allowed_by_robots(url: str) -> bool:
        parsed = urllib.parse.urlparse(url)
        base = f"{parsed.scheme}://{parsed.netloc}"
        if base not in robot_cache:
            rp = urllib.robotparser.RobotFileParser()
            try:
                rp.set_url(urllib.parse.urljoin(base, "/robots.txt"))
                rp.read()
            except Exception:
                pass
            robot_cache[base] = rp
        try:
            return robot_cache[base].can_fetch(USER_AGENT, url)
        except Exception:
            return True

    seen, url_map = set(), {}
    q = queue.Queue()
    for s in seeds:
        q.put(s); seen.add(s)

    n_saved = 0
    while not q.empty() and n_saved < MAX_PAGES:
        url = q.get()
        if not same_registered_domain(url, allowed):
            continue
        if not allowed_by_robots(url):
            continue
        try:
            time.sleep(SLEEP)
            resp = fetch(url)
        except Exception:
            continue

        fname = RAW_DIR/safe_name(url)
        try:
            with open(fname, "wb") as f:
                f.write(resp.content)
            url_map[fname.name] = url
            n_saved += 1
            print(f"[{n_saved}] {url} -> {fname.name}")
        except Exception:
            continue

        if (not is_pdf(url)) and "text/html" in resp.headers.get("Content-Type",""):
            try:
                for l in extract_links(resp.text, url):
                    if l not in seen and same_registered_domain(l, allowed):
                        seen.add(l); q.put(l)
            except Exception:
                pass

    (RAW_DIR/"url_map.json").write_text(json.dumps(url_map, indent=2), encoding="utf-8")
    print(f"Done. Saved {n_saved} files. URL map at {URLMAP_PATH}")

crawl()
# Out:
# /tmp/ipython-input-1481669232.py:32: DeprecationWarning: The 'registered_domain' property is deprecated and will be removed in the next major version. Use 'top_domain_under_public_suffix' instead, which has the same behavior but a more accurate name.
#   allowed.add(tldextract.extract(host).registered_domain)
# /tmp/ipython-input-1481669232.py:23: DeprecationWarning: The 'registered_domain' property is deprecated and will be removed in the next major version. Use 'top_domain_under_public_suffix' instead, which has the same behavior but a more accurate name.
#   reg = tldextract.extract(host).registered_domain
# Allowed domains: ['carnegiemuseums.org', 'cmu.edu', 'downtownpittsburgh.com', 'heinzhistorycenter.org', 'littleitalydays.com', 'mlb.com', 'nhl.com', 'pghrestaurantweek.com', 'pghtacofest.com', 'picklesburgh.com', 'pittsburghcitypaper.com', 'pittsburghpa.gov', 'pittsburghsymphony.org', 'steelers.com', 'thefrickpittsburgh.org', 'trustarts.org', 'visitpittsburgh.com', 'wikipedia.org']
# [1] https://www.visitpittsburgh.com/ -> 2b253825728e9152.html
# [2] https://pittsburghpa.gov/ -> b463e569cbb6d2f1.html
# [3] https://www.cmu.edu/ -> b993bc448dbf10fd.html
# [4] https://www.cmu.edu/events/ -> dc8eb38b8517024e.html
# [5] https://www.thefrickpittsburgh.org/ -> b63c572668c8a830.html
# [6] https://downtownpittsburgh.com/events/ -> b504b92ecbe57939.html
# [7] https://www.pghtacofest.com/ -> c4f3c615c4d4aed4.html
# [8] https://www.mlb.com/pirates -> f7935da9f95dd5cb.html
# [9] https://www.steelers.com/ -> b7e85f22b943fed1.html
# [10] https://www.visitpittsburgh.com/things-to-do/family-fun/ -> 38e0e4551bebfe27.html
# [11] https://www.visitpittsburgh.com/plan-your-trip/group-tour/ -> c8e5a274399a913f.html
# [12] https://www.visitpittsburgh.com/neighborhoods/ -> bd37ce736b0895eb.html
# [13] https://www.visitpittsburgh.com/restaurants-culinary/craft-breweries/ -> f1c126acd463a35a.html
# [14] https://www.visitpittsburgh.com/plan-your-trip/pet-friendly-travel/ -> 8e676dc1a699c3a4.html
# [15] https://www.visitpittsburgh.com/events-festivals/submit-your-event/ -> 499f9c2662719af2.html
# [16] https://www.visitpittsburgh.com/blog/cozy-coffee-shops-in-pittsburgh/ -> ba7e39fe743d764c.html
# [17] https://www.visitpittsburgh.com/things-to-do/free-things-to-do/ -> 10d15b11f17adffc.html
# [18] https://www.visitpittsburgh.com/meetings-and-events/request-for-proposal/ -> 09dc253bbb13a4b1.html
# [19] https://www.visitpittsburgh.com/america-250/ -> 9a06852c04e2c077.html
# [20] https://www.visitpittsburgh.com/things-to-do/casinos-gaming/ -> 484d38c6160efb6f.html
# [21] https://www.visitpittsburgh.com/events-festivals/ -> 37e6cbdfd9440a1a.html
# [22] https://www.visitpittsburgh.com/events-festivals/this-week-in-pittsburgh/ -> 511d938ae93028ce.html
# [23] https://www.visitpittsburgh.com/hotels-resorts/ -> a2aaa8deba721cfd.html
# [24] https://www.visitpittsburgh.com/media/ -> 80de76bbfc3c1d1a.html
# [25] https://www.visitpittsburgh.com/plan-your-trip/weather/ -> d6bf08c7c65f606d.html
# [26] https://www.visitpittsburgh.com/directory/pittsburgh-zoo-aquarium/ -> db40cc6cd319d5bf.html
# [27] https://www.visitpittsburgh.com/contact-us/ -> 853aad43b291036c.html
# [28] https://www.visitpittsburgh.com/plan-your-trip/senior-travel/ -> 3ecc24bf628aa713.html
# [29] https://www.visitpittsburgh.com/things-to-do/arts-culture/ -> d4386424d980155a.html
# [30] https://www.visitpittsburgh.com/events-festivals/film-festivals/ -> dcd7ff8bfb84e1a5.html
# [31] https://www.visitpittsburgh.com/plan-your-trip/accessibility-guide/ -> 51cf0d815343bd51.html
# [32] https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/ -> d282e29c8175b0e0.html
# [33] https://www.visitpittsburgh.com/things-to-do/ -> 38803159ec352d48.html
# [34] https://www.visitpittsburgh.com/plan-your-trip/college-visits/ -> 1d932a9d20454d68.html
# [35] https://www.visitpittsburgh.com/meetings-and-events/ -> 035ac21279fc67b1.html
# [36] https://www.visitpittsburgh.com/blog/apple-picking-pumpkin-patches-day-trips-from-pittsburgh-for-fall-fun/ -> fa9f619ee450bb33.html
# [37] https://www.visitpittsburgh.com/plan-your-trip/welcome-centers/ -> 76973f6004b0a218.html
# [38] https://www.visitpittsburgh.com/plan-your-trip/newsletter-signup/ -> b51c11d25e56c882.html
# [39] https://www.visitpittsburgh.com/directory/kennywood/ -> f4cc78622314b624.html
# [40] https://www.visitpittsburgh.com/blog/particular-brand-of-magic-pittsburgh-ranks-in-lonely-planets-top-10-global-best-in-travel-2025-list/ -> 0d7c42597a02a2fb.html
# [41] https://www.visitpittsburgh.com/meetings-and-events/meeting-planner-toolkit/ -> 07193efa8d126d6a.html
# [42] https://www.visitpittsburgh.com/things-to-do/shopping/ -> 6c0c3c47f07ac9ea.html
# [43] https://www.visitpittsburgh.com/blog/the-countdown-is-on-for-the-2026-nfl-draft-in-pittsburgh/ -> af7140dbefef904f.html
# [44] https://www.visitpittsburgh.com/plan-your-trip/medical-travel/ -> 91e58b78ba4fbe3f.html
# [45] https://www.visitpittsburgh.com/plan-your-trip/beyond-pittsburgh/ -> f59c627538fd7049.html
# [46] https://www.visitpittsburgh.com/partners/ -> cba1ae0e51445e06.html
# [47] https://www.visitpittsburgh.com/nfl-draft-pittsburgh/ -> 6df2c1ae18e33ea6.html
# [48] https://www.visitpittsburgh.com/restaurants-culinary/ -> 699acb1509e03c40.html
# [49] https://www.visitpittsburgh.com/events-festivals/annual-events/ -> eaeaf0b6c946a3e7.html
# [50] https://www.visitpittsburgh.com/events-festivals/holidays/ -> b583c3fb3f915667.html
# [51] https://www.visitpittsburgh.com/blog/ -> fcc27321e132ecd8.html
# [52] https://www.visitpittsburgh.com/events-festivals/food-festivals/ -> e8c6570895c39f02.html
# [53] https://www.visitpittsburgh.com/plan-your-trip/transportation/ -> f41efaa94d8daff4.html
# [54] https://www.visitpittsburgh.com/plan-your-trip/explore-black-culture-heritage/ -> c943ce1a7a2da5b7.html
# [55] https://www.visitpittsburgh.com/plan-your-trip/lgbtq-travel/ -> b55e512530a783cf.html
# [56] https://www.visitpittsburgh.com/search/ -> 67f4fa320a115cb4.html
# [57] https://www.visitpittsburgh.com/meetings-and-events/show-your-badge/ -> f6fcbd8099438ae1.html
# [58] https://www.visitpittsburgh.com/meetings-and-events/hotels/ -> 2b7449fde12dbce8.html
# [59] https://www.visitpittsburgh.com/directory/pittsburgh-steelers/ -> ee4b7ab2e24c8722.html
# [60] https://www.visitpittsburgh.com/events-festivals/marathons-runs-walks/ -> 4ea11aeb48e24e89.html
# [61] https://www.visitpittsburgh.com/restaurants-culinary/farms-farmers-markets/ -> 0a7023f3e72094ad.html
# [62] https://www.visitpittsburgh.com/about-us/ -> 49468c2a807e8117.html
# [63] https://www.visitpittsburgh.com/meetings-and-events/reasons-to-meet-in-pittsburgh/ -> 0b5528ece9a3675e.html
# [64] https://www.visitpittsburgh.com/weddings-reunions/ -> d378cb1e08b83f9c.html
# [65] https://www.visitpittsburgh.com/events-festivals/halloween-events/ -> c5007ab3494ebbb5.html
# [66] https://www.visitpittsburgh.com/plan-your-trip/visitors-guide/ -> 1d3f2016c250cfdb.html
# [67] https://www.visitpittsburgh.com/directory/pittsburgh-penguins/ -> c778ab046d5fe745.html
# [68] https://www.visitpittsburgh.com/events-festivals/oktoberfest-pittsburgh/ -> 5555fc2da99ae8fe.html
# [69] https://www.visitpittsburgh.com/plan-your-trip/ -> 7cb3d3b7921f1362.html
# [70] https://www.visitpittsburgh.com/restaurants-culinary/bars-nightlife/ -> 95e90c3db364ddb6.html
# [71] https://www.visitpittsburgh.com/meetings-and-events/event-services/ -> 3efeeeea56f00c19.html
# [72] https://www.visitpittsburgh.com/privacy/ -> 02688fc3d4d037d6.html
# [73] https://www.visitpittsburgh.com/blog/fall-fairs-festivals-and-events/ -> ac23cc51eaa146d2.html
# [74] https://www.visitpittsburgh.com/things-to-do/health-wellness/ -> 480f450757c7b950.html
# [75] https://www.visitpittsburgh.com/things-to-do/outdoor-adventure/ -> 68ad2b3ae498c014.html
# [76] https://www.visitpittsburgh.com/things-to-do/tours-sightseeing/ -> 1fddcd0e7241aa2c.html
# [77] https://www.visitpittsburgh.com/itinerary/ -> a2074b396ae2f06d.html
# [78] https://www.visitpittsburgh.com/restaurants-culinary/wineries-distilleries/ -> 84f0c82d6eb0a53d.html
# [79] https://www.visitpittsburgh.com/meetings-and-events/contact-us/ -> a8cb7d714bdc4696.html
# [80] https://www.pittsburghpa.gov/City-Government/Mayor/City-of-Pittsburgh-Charity-Challenges-FAQs -> f575b3e5d18382bc.html
# [81] https://www.pittsburghpa.gov/Recreation-Events/Pools/Citiparks-Lifeguard -> 386ceb38f034cf52.html
# [82] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Special-Event-Recycling -> 0f3cb21da70b521f.html
# [83] https://www.pittsburghpa.gov/Safety -> 8c4d000444af89e0.html
# [84] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Condemned-Buildings -> b96d52c856288ae4.html
# [85] https://www.pittsburghpa.gov/City-Government/Jobs/Human-Resources-and-Civil-Service -> 9fa3383cd2bce671.html
# [86] https://www.pittsburghpa.gov/City-Government/Finance-Budget/New-Business-Registration -> 58004015612b9989.html
# [87] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Taxes -> e39f187b6d0332cb.html
# [88] https://www.pittsburghpa.gov/Resident-Services/Pets-Animals -> ecee56b76624b608.html
# [89] https://www.pittsburghpa.gov/City-Government/Legal-Services/Ethics-Hearing-Board -> baa2a745e531be41.html
# [90] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/FAQ -> adce2a2d6be08c62.html
# [91] https://www.pittsburghpa.gov/Business-Development/Zoning/Plan-Reviews-and-Notices -> a638d0c9c00d1da4.html
# [92] https://www.pittsburghpa.gov/News-articles/Homepage/CITY-OF-PITTSBURGH-LAUNCHES-PILOT-HOME-BUYING-PROGRAM-TO-EXPAND-ACCESS-TO-HOMEOWNERSHIP -> b6209e6dd4422ccd.html
# [93] https://www.pittsburghpa.gov/Resident-Services/Road-Maintenance/Paving-Schedule -> de7f1a898388b988.html
# [94] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/City-County-Task-Force-on-Disability -> a91a21856d600f54.html
# [95] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Dog-Licenses -> bd1f676e2f6c5949.html
# [96] https://www.pittsburghpa.gov/Business-Development/PGH-Lab -> 902872f77094e62c.html
# [97] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Statutes-Policies/Website-Accessibility -> e0b3dbe05590d2be.html
# [98] https://www.pittsburghpa.gov/Business-Development/Procurement/Procurement-Resources -> accbe0eebd283118.html
# [99] https://www.pittsburghpa.gov/Resident-Services/Road-Maintenance -> 5a0159b512cde5a7.html
# [100] https://www.pittsburghpa.gov/Business-Development/City-Planning -> a763dc8a4b00ff8f.html
# [101] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Make-an-Accommodations-Request -> 0a2f499ba75acb86.html
# [102] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Commercial-Recycling -> b17aa75f3919e92c.html
# [103] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Announcements -> 7178a1cf30202a8c.html
# [104] https://www.pittsburghpa.gov/Recreation-Events/Events/Pittsburgh-Cultural-Activities -> 98b9525fe7d25ef6.html
# [105] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/About-the-Controller -> 3beb2dcd51d6a4ee.html
# [106] https://www.pittsburghpa.gov/Recreation-Events/Park-Facilities -> 261ae38a969fb866.html
# [107] https://www.pittsburghpa.gov/Business-Development/Sustainability -> 598c9f47a7ea4d38.html
# [108] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Plans -> 9113116754e6f79e.html
# [109] https://www.pittsburghpa.gov/Business-Development -> 77dd035e3c812192.html
# [110] https://www.pittsburghpa.gov/Resident-Services/Community-Programming/Black-Pittsburgh-Matters -> cf584e52c694be13.html
# [111] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/Benefits -> 5b60991e11d12e62.html
# [112] https://www.pittsburghpa.gov/Business-Development/City-Planning/Process-Guides -> 4d0c2dfd851dab65.html
# [113] https://www.pittsburghpa.gov/Resident-Services/Food-Programs/Summer-Food-Program -> 52859e6fbe6ff272.html
# [114] https://www.pittsburghpa.gov/Safety/Public-Safety/Animal-Care-Control -> c350a1fe37a32ebe.html
# [115] https://www.pittsburghpa.gov/Resident-Services/Food-Programs/After-School-Feeding-Program -> ce42545b5fb002a3.html
# [116] https://www.pittsburghpa.gov/News-articles/Homepage/The-23rd-Annual-Gingerbread-House-Competition-Accepting-Entries-Beginning-October-1 -> fb8f8a4c26e75b36.html
# [117] https://www.pittsburghpa.gov/Safety/Police/File-a-Police-Report -> a0948ae0eb37d235.html
# [118] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Collection-Schedule-and-Newsletter -> 5e5801ae4337190e.html
# [119] https://www.pittsburghpa.gov/Recreation-Events/About-Parks -> d828327c12b6687a.html
# [120] https://www.pittsburghpa.gov/City-Government/Legal-Services -> ee893853f26394cc.html
# [121] https://www.pittsburghpa.gov/Business-Development/City-Planning/Historic-Preservation-Program -> 91d80f54bc35baf2.html
# [122] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/ADA-FAQs -> 75ad20e842b1e92f.html
# [123] https://www.pittsburghpa.gov/Safety/Alerts -> 35dcbb9581a064f9.html
# [124] https://www.pittsburghpa.gov/Safety/Fire/Districts-Zones -> 6aa2fa03f33b3a44.html
# [125] https://www.pittsburghpa.gov/Business-Development/City-Planning/Public-Art -> 61d4b83551d64667.html
# [126] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Finance-Fee-Schedule -> 6635a7668caa2b7a.html
# [127] https://www.pittsburghpa.gov/City-Government/Boards-Authorities-Commissions -> 706376968547dec2.html
# [128] https://www.pittsburghpa.gov/City-Government/Mayor/2025-Governing-Agenda -> cde57700fcc33605.html
# [129] https://www.pittsburghpa.gov/Resident-Services/Road-Maintenance/Street-Maintenance -> 6c72fdf8c3dcf9a2.html
# [130] https://www.pittsburghpa.gov/City-Government/Legal-Services/Office-of-Municipal-Investigations -> 34f1df5b8edaf541.html
# [131] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Dog-Licenses -> 21f5b10827b191c2.html
# [132] https://www.pittsburghpa.gov/Business-Development/Procurement/Certified-Vendor-List -> 0eedd6dc814ff477.html
# [133] https://www.pittsburghpa.gov/Business-Development/Sustainability/Resilient-Pittsburgh -> 8c81394692fd41b6.html
# [134] https://www.pittsburghpa.gov/Safety/Animal-Care-Control -> 67c2627814bf105a.html
# [135] https://www.pittsburghpa.gov/City-Government/Mayor/Youth-Civic-Leadership-Academy -> c8241f788465e306.html
# [136] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/Alumni -> 924a50b9e2bfc3c3.html
# [137] https://www.pittsburghpa.gov/Recreation-Events/Pools -> fe40e686bce12901.html
# [138] https://www.pittsburghpa.gov/Business-Development/Procurement/Beacon-FAQs -> 626f268d184fd17f.html
# [139] https://www.pittsburghpa.gov/Safety/Public-Safety/Violence-Prevention -> 127124498cf10517.html
# [140] https://www.pittsburghpa.gov/Recreation-Events/Parks/Dog-Parks -> bd4f340b9d63e650.html
# [141] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management/Special-Event-Block-Party-Permitting -> e8b53b8356af1ab6.html
# [142] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Appeals -> 1a278339af2b3533.html
# [143] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Beekeeping-and-Farm-Animal-Permits -> 5a7effa537dbe444.html
# [144] https://www.pittsburghpa.gov/Business-Development/City-Planning/Master-Neighborhood-Plans -> 188aeba39a43cbfb.html
# [145] https://www.pittsburghpa.gov/Safety/Police -> 84ffeadc074c5a98.html
# [146] https://www.pittsburghpa.gov/Business-Development/Sustainability/Environmental-Planning-and-Review -> 536dd78fae0b8f8e.html
# [147] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Permits -> eee5b55d03fd7324.html
# [148] https://www.pittsburghpa.gov/Events-directory/CitiParks-Announces-Annual-Track-and-Treat-Event -> c394de56569441d9.html
# [149] https://www.pittsburghpa.gov/City-Government/City-Council/Council-Budget-Office -> 51dea227e8fe36e3.html
# [150] https://www.pittsburghpa.gov/City-Government/Mayor/Pittsburgh-Innovation-Team -> d3ef6a4d02bea4e5.html
# [151] https://www.pittsburghpa.gov/Business-Development/Public-Works/Contact-Public-Works -> ebd42b28c3998f74.html
# [152] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/About-Mobility-and-Infrastructure -> 9f03fc6af5c8320c.html
# [153] https://www.pittsburghpa.gov/City-Government/Mayor/Contact -> fdbcdda2382fd04c.html
# [154] https://www.pittsburghpa.gov/City-Government/Jobs/Careers -> df095e1a52bb2740.html
# [155] https://www.pittsburghpa.gov/Safety/Police/Branches -> e30e90ee40f817f3.html
# [156] https://www.pittsburghpa.gov/Resident-Services/Food-Programs -> bb70a0776b19c16c.html
# [157] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Meet-the-Staff -> 2790d04b6609bf7a.html
# [158] https://www.pittsburghpa.gov/Safety/Public-Safety/Emergency-Management-and-Homeland-Security -> fd2c92516c28a675.html
# [159] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/OEP-News -> 231feb4cb48b1640.html
# [160] https://www.pittsburghpa.gov/Recreation-Events/Park-Facilities/The-Neill-Log-House -> 3d490630c8080a8b.html
# [161] https://www.pittsburghpa.gov/Business-Development/City-Planning/Planning-Programs -> b38b27af46bbbaba.html
# [162] https://www.pittsburghpa.gov/City-Government/Mayor/Biography -> 1ee91aa41ebdb2ea.html
# [163] https://www.pittsburghpa.gov/Resident-Services/Snow-Removal/Snow-Ice -> eca760f4ed501ec5.html
# [164] https://www.pittsburghpa.gov/Business-Development/Public-Works/Street-Maintenance-Bureau -> 04a8f7fdbf1d5376.html
# [165] https://www.pittsburghpa.gov/News-articles/Homepage/CITY-OF-PITTSBURGH-TO-CLOSE-PJ-MCARDLE-ROADWAY-AND-BECKS-RUN-ROAD-FOR-CLEAN-UP-EFFORTS-ON-OCTOBER-4TH-AND-5TH -> d139519ca7679cff.html
# [166] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Announcements-Press-Releases -> 12fae7294e2285a9.html
# [167] https://www.pittsburghpa.gov/City-Government/Legal-Services/File-a-Claim-with-Law -> e796b5417295f17f.html
# [168] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Disability-Rights-Brochure -> 9647c15f908c229b.html
# [169] https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Citiparks-Phone-Directory -> 9c15a702c220cf07.html
# [170] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling -> 6974a679ed05d666.html
# [171] https://www.pittsburghpa.gov/Business-Development/City-Planning/Commissions-and-Boards -> e4e43f098f363df5.html
# [172] https://www.pittsburghpa.gov/Recreation-Events/Park-Permits/Sports-Field-Permit -> 9071779fc40bb825.html
# [173] https://www.pittsburghpa.gov/Safety/Police/About-Police -> b989ab3515d4d9bf.html
# [174] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/SpayNeuter-Program -> 71fd069d3060869f.html
# [175] https://www.pittsburghpa.gov/Safety/Alerts/Public-Safety-Blotter -> 6cc8361f76aed6d7.html
# [176] https://www.pittsburghpa.gov/Business-Development/Zoning/Planning-Application-and-Process -> 37b6dd8c9c9bcf57.html
# [177] https://www.pittsburghpa.gov/Resident-Services/Community-Programming/Snow-Angels -> c105d3766e84ad1f.html
# [178] https://www.pittsburghpa.gov/Events-directory/Gingerbread-House-Competition-Accepting-Entries-Beginning-October-1 -> 48d08ce0983258ba.html
# [179] https://www.pittsburghpa.gov/City-Government/Mayor/Newsletters -> fe9c0569338b5d1f.html
# [180] https://www.pittsburghpa.gov/Recreation-Events/Special-Events -> 808cb8bab2bc6b25.html
# [181] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Fiscal-Focus-PGH -> 3c7871ccafc56581.html
# [182] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Management-Budget -> 97d090125668d58f.html
# [183] https://www.pittsburghpa.gov/Business-Development/Sustainability/Sustainability-Resilience-Library -> 2819365d5326aabb.html
# [184] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights -> 92ee3ae5bf84b372.html
# [185] https://www.pittsburghpa.gov/Safety/Public-Safety/Nighttime-Economy -> 5746fa8e2ca79db3.html
# [186] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Rescue-Division -> bcff886e71face7b.html
# [187] https://www.pittsburghpa.gov/Resident-Services/Tree-Resources/Forestry-Division -> 8c2ae5fbba8dd2c2.html
# [188] https://www.pittsburghpa.gov/City-Government/City-Council/Council-Contacts -> b8110384f31d83fc.html
# [189] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Annual-Reports -> 6b04a662e11b8f4e.html
# [190] https://www.pittsburghpa.gov/Safety/Public-Safety/National-Night-Out -> 282904408731772d.html
# [191] https://www.pittsburghpa.gov/Business-Development/Public-Works/Environmental-Services -> c1548573f8996152.html
# [192] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Ambulance-Division -> ac3671c796f5d7a7.html
# [193] https://www.pittsburghpa.gov/City-Government/Mayor/Executive-Orders -> 6a9a4d2d0071c7a8.html
# [194] https://www.pittsburghpa.gov/Business-Development/Zoning -> 113e8882d08e1dc1.html
# [195] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Transportation-Development-Review -> e40968861bd1cf12.html
# [196] https://www.pittsburghpa.gov/Recreation-Events/Pools/Outdoor-Pools -> 46de0208005ac744.html
# [197] https://www.pittsburghpa.gov/City-Government/Contacts-Information -> 6cae75697fec6077.html
# [198] https://www.pittsburghpa.gov/Business-Development/Sustainability/Building-Benchmarking-Compliance -> 15f9f5568e625616.html
# [199] https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Parks-FAQ -> 2d874350be4aa372.html
# [200] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/EMS-Contacts -> b1e62122d0888451.html
# [201] https://www.pittsburghpa.gov/City-Government/City-Council/Clerks-Office -> 4ffa4d1cd528ca0c.html
# [202] https://www.pittsburghpa.gov/Safety/Alerts/Emergency-Updates -> 97a59ee4408c82de.html
# [203] https://www.pittsburghpa.gov/Safety/Alerts/Public-Safety-Press-Release-Archive -> 86fdf5efdb689910.html
# [204] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Licenses -> 83e13af927bbe83e.html
# [205] https://www.pittsburghpa.gov/Recreation-Events/Parks/Tennis -> 842847ca66aeb248.html
# [206] https://www.pittsburghpa.gov/Business-Development/Sustainability/Climate-Action-Plan -> 1adfcda2292c8cc8.html
# [207] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Special-Programs -> f702972972c6bf52.html
# [208] https://www.pittsburghpa.gov/City-Meeting-Hub -> b9749b4569ae11c5.html
# [209] https://www.pittsburghpa.gov/Recreation-Events/Events/Roving-Art-Cart -> 0e16beece9909c45.html
# [210] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Plans/City-Bridges -> 4e2d388bed19f577.html
# [211] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Applications-Forms -> c9614973f2adab46.html
# [212] https://www.pittsburghpa.gov/Safety/Public-Safety/Disruptive-Properties -> 1b7556b4b1392562.html
# [213] https://www.pittsburghpa.gov/Safety/Police/Police-Zones -> 53b964801c1e75f8.html
# [214] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Fees -> 3bbfa3a128fbf00c.html
# [215] https://www.pittsburghpa.gov/City-Government/Finance-Budget -> 2ca0c7623ee41a35.html
# [216] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Health-and-Safety-Resources -> 6b1107b85c24ebaa.html
# [217] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Black-History-Month -> 1c614a0ed2772e4b.html
# [218] https://www.pittsburghpa.gov/City-Government/City-Council/Neighborhoods-Wards -> e79d266fc8fe2548.html
# [219] https://www.pittsburghpa.gov/Business-Development/City-Planning/Public-Notices -> fdd90ae7553e5903.html
# [220] https://www.pittsburghpa.gov/Resident-Services/Community-Programming/Love-Your-Block -> ee3ee93e69f8dcde.html
# [221] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Contacts -> acd4fabba692432c.html
# [222] https://www.pittsburghpa.gov/Safety/Public-Safety/Public-Safety-Contacts -> 914a2a3886208ff1.html
# [223] https://www.pittsburghpa.gov/Safety/Police/Police-Data-Portal -> 8bad0108ee83818a.html
# [224] https://www.pittsburghpa.gov/City-Government/Boards-Authorities-Commissions/Agendas-Minutes -> e9c0675bf7209d87.html
# [225] https://www.pittsburghpa.gov/Business-Development/Sustainability/Food-Systems -> f52916eadf3795aa.html
# [226] https://www.pittsburghpa.gov/City-Government/Mayor/City-County-Building -> c12ddb1cef3f0377.html
# [227] https://www.pittsburghpa.gov/Business-Development/Small-Business-Resources/OneStopPGH-Tips-for-Small-Businesses -> 3589f2d325d33224.html
# [228] https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Parks-Rules -> 435e475aa6c7d264.html
# [229] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Community-Festivals -> e6c6a6125f4217b9.html
# [230] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/CCB-Accessibility-Entrance -> 685a6af01cee70e4.html
# [231] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Special-Event-Operations -> fb036440f3e1c51a.html
# [232] https://www.pittsburghpa.gov/Recreation-Events/Events/Farmers-Markets -> 816a98e10cf6c9b5.html
# [233] https://www.pittsburghpa.gov/Recreation-Events/Parks/For-Kids -> e259610baac99ed4.html
# [234] https://www.pittsburghpa.gov/Recreation-Events/Parks/CitiSports -> 9519629871a0e7fc.html
# [235] https://www.pittsburghpa.gov/City-Government/Boards-Authorities-Commissions/Member-Rosters -> 517ed49cfda008b0.html
# [236] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Campaign-Finances -> bc736d89b84822c6.html
# [237] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/Home -> 2c997f16982f1aea.html
# [238] https://www.pittsburghpa.gov/Safety/Public-Safety/Office-of-Film-Event-Management -> 62b1a674d02b8e73.html
# [239] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management/Special-Events-Committee -> f37f7a5bf6f45f91.html
# [240] https://www.pittsburghpa.gov/Site-Footer/Footer-Widgets/Contact-Us -> 3631d69c066af650.html
# [241] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Disability-Rights-Brochure-Screen-Reader-Accessible-Version -> 652d22f5e84fd8cb.html
# [242] https://www.pittsburghpa.gov/Safety/Fire/About-Fire -> 5d419372bafc80c7.html
# [243] https://www.pittsburghpa.gov/Safety/Fire/Firefighter-Recruitment -> ab8e8ac53292fe43.html
# [244] https://www.pittsburghpa.gov/Business-Development/Digital-Equity-In-Pittsburgh/Media-and-Information-Resources -> 5aa079a2cab6e1e5.html
# [245] https://www.pittsburghpa.gov/Business-Development/Procurement -> 5bb2522fa13f61cc.html
# [246] https://www.pittsburghpa.gov/Recreation-Events/Events/Dollar-Bank-Cinema-In-The-Park -> e42672c0525e70fb.html
# [247] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Code-Enforcement -> 1854404f182d8e86.html
# [248] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Community-Engagement -> 5489459d07b26bd4.html
# [249] https://www.pittsburghpa.gov/Recreation-Events/Events/Summer-Soul-Line-Dancing -> 3300f2b8b4d1656c.html
# [250] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Juneteenth-Celebrations -> d20aecf3d94fcedb.html
# [251] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Pittsburgh-E-Arena-Tournament -> e8da1de38b569191.html
# [252] https://www.pittsburghpa.gov/Business-Development/Public-Works/Forestry-Division -> 8bb9c55f20e905c0.html
# [253] https://www.pittsburghpa.gov/Business-Development/Small-Business-Resources -> 2eb7932d1149c4d0.html
# [254] https://www.pittsburghpa.gov/Business-Development/Zoning/Housing -> 1c6b059b1b85b61a.html
# [255] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Newsletter -> d131bf02bd6a574d.html
# [256] https://www.pittsburghpa.gov/News-articles/Homepage/TRAFFIC-CALMING-PROJECT-BEGINS-ON-SOUTHERN-AVENUE-AS-PART-OF-VISION-ZERO-IMPLEMENTATION-EFFORTS -> fe9fbae7e26a8762.html
# [257] https://www.pittsburghpa.gov/Recreation-Events/Events/Pistons-in-the-Park-Car-Cruise -> 1386ec806ce98857.html
# [258] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Contact-Special-Events -> c970ca2c3bd8f47d.html
# [259] https://www.pittsburghpa.gov/City-Government/Mayor/My-Brothers-Keeper -> c204f0017ff19d41.html
# [260] https://www.pittsburghpa.gov/City-Government/City-Council -> ea190a1b2c8bc4e0.html
# [261] https://www.pittsburghpa.gov/Recreation-Events/Parks/Outdoor-Activities -> e6323bef378c75ad.html
# [262] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure -> dcab628884a039e1.html
# [263] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections -> fab93c6fc150a905.html
# [264] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Right-of-Way-Management -> d5ceadc783b42412.html
# [265] https://www.pittsburghpa.gov/City-Government/City-Council/Districts -> f0f13edb449f6810.html
# [266] https://www.pittsburghpa.gov/City-Government/Boards-Authorities-Commissions/List-of-Boards-Authorities-Commissions -> 2ce6d4c5059c5e2d.html
# [267] https://www.pittsburghpa.gov/City-Government/Mayor/Press-Releases -> 4e908e51e93f644e.html
# [268] https://www.pittsburghpa.gov/Recreation-Events -> d43f21444c4c9fec.html
# [269] https://www.pittsburghpa.gov/City-Government/Contacts-Information/Web-Disclaimers -> 74b609ac62897195.html
# [270] https://www.pittsburghpa.gov/Recreation-Events/Parks -> 8baae95a60445e49.html
# [271] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Maps -> 0ebcbc2f6ee879dc.html
# [272] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Stray-Animals -> 231a0a820459bd0c.html
# [273] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Curbside-Pick-Up -> 8422d0e7463952fd.html
# [274] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Training-Division -> caafefa62ee4cbf0.html
# [275] https://www.pittsburghpa.gov/Safety/Fire/Bureau-of-Fire-Contacts -> c6a26c3f5d12524a.html
# [276] https://www.pittsburghpa.gov/Recreation-Events/Events/ARTWorks -> a0ba6bd5d5911883.html
# [277] https://www.pittsburghpa.gov/Business-Development/Procurement/City-Buying-Plan -> 225c80ef1a935111.html
# [278] https://www.pittsburghpa.gov/City-Government/Jobs -> 6a4c36e12073f93b.html
# [279] https://www.pittsburghpa.gov/Recreation-Events/Park-Permits -> 3aba001d8cbf3e69.html
# [280] https://www.pittsburghpa.gov/Resident-Services/Snow-Removal -> f86d8d0e05e65d40.html
# [281] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Registrations -> cf2265bc85f6a5cf.html
# [282] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management -> d69cee4aadc26ba5.html
# [283] https://www.pittsburghpa.gov/Resident-Services/Tree-Resources -> 4897707f3fa54df1.html
# [284] https://www.pittsburghpa.gov/City-Government -> 5f52e2a5e04892ad.html
# [285] https://www.pittsburghpa.gov/Business-Development/Procurement/Beacon -> b48f0d59c0c33806.html
# [286] https://www.pittsburghpa.gov/Recreation-Events/Parks/Community-Garden-Plots -> e435e2c883b2341f.html
# [287] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services -> 14cf99fc437d9554.html
# [288] https://www.pittsburghpa.gov/Resident-Services/311/Contacting-311 -> 2a4e3636b103744f.html
# [289] https://www.pittsburghpa.gov/Resident-Services/Immigrant-and-Refugee-Affairs -> 78a80c9c03ce0305.html
# [290] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Disability-Resources-Center -> 2e18b3a9c2ffc832.html
# [291] https://www.pittsburghpa.gov/Recreation-Events/Parks/City-Farms -> 9be5bfd5bfdea685.html
# [292] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/PLI-Bulletins -> 78900d90b395ed67.html
# [293] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/Contact-Us -> b0baf6c0d7111416.html
# [294] https://www.pittsburghpa.gov/City-Government/Mayor/Office-of-Immigrant-and-Refugee-Affairs -> 645d75086b25c9ea.html
# [295] https://www.pittsburghpa.gov/Business-Development/City-Planning/About-DCP -> 5f72ef74bce62e16.html
# [296] https://www.pittsburghpa.gov/Recreation-Events/Events/Summer-Guide -> a42cd969ec22ab7e.html
# [297] https://www.pittsburghpa.gov/City-Government/Legal-Services/Department-of-Law -> a3f2fa19d04b1caf.html
# [298] https://www.pittsburghpa.gov/Recreation-Events/Events/Concerts -> 68258b390a06f414.html
# [299] https://www.pittsburghpa.gov/Recreation-Events/Parks/For-Seniors -> 295e13634fbb3a91.html
# [300] https://www.pittsburghpa.gov/Business-Development/Geographic-Information-Systems-Mapping-Open-Data -> fe9afadaa6e9fcea.html
# [301] https://www.pittsburghpa.gov/Resident-Services/Snow-Removal/Snow-Plow-Tracker -> ac23a6b9aee943ce.html
# [302] https://www.pittsburghpa.gov/City-Government/Contacts-Information/City-Directory -> 90dbd51c11cc5b22.html
# [303] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety -> 9303eaf430e9a590.html
# [304] https://www.pittsburghpa.gov/City-Government/Mayor/Key-Focus-Areas -> 873e1f4d6c6e0052.html
# [305] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Disclosure-of-Interest-Reports -> 29c6f1d799620238.html
# [306] https://www.pittsburghpa.gov/Business-Development/Sustainability/Affiliations-Memberships -> f71c7ccc65d25338.html
# [307] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Animal-Control-FAQs -> 609fd23cd256ada4.html
# [308] https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Park-Maintenance -> 017818693127d866.html
# [309] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Drop-Off-Info-Additional-Resources -> 38ca223040fb01d6.html
# [310] https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Park-Rangers -> 7d31861a9d71922f.html
# [311] https://www.pittsburghpa.gov/Recreation-Events/Pools/Oliver-Bath-House -> 2c5e26e3e43be0c0.html
# [312] https://www.pittsburghpa.gov/Resident-Services/Community-Programming/City-Cuts -> 3814a5ae72d95bba.html
# [313] https://www.pittsburghpa.gov/Recreation-Events/Events/Footraces -> 9f7ef8601a253974.html
# [314] https://www.pittsburghpa.gov/Resident-Services/Road-Maintenance/Road-Safety -> e937e0742392a3e6.html
# [315] https://www.pittsburghpa.gov/Business-Development/Procurement/Bid-Opportunities -> 1451c3a79fe96502.html
# [316] https://www.pittsburghpa.gov/Home -> c9dc9f1ae3247e05.html
# [317] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Unclaimed-Property -> 1197f6323cd6ad4c.html
# [318] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Join-Our-Team -> a4b066d227335cf0.html
# [319] https://www.pittsburghpa.gov/Events-directory -> 6f6a9fbe6e25f3d4.html
# [320] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Become-a-Paramedic -> b5b41d59f81e848f.html
# [321] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Take-Our-Accessibility-Survey -> ea962ced876a6e9a.html
# [322] https://www.pittsburghpa.gov/Business-Development/Public-Works -> 1cbe741755d86738.html
# [323] https://www.pittsburghpa.gov/Recreation-Events/Pools/Spray-Parks -> 8536f3f81f28d47a.html
# [324] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Pilot-Home-Buying-Program -> 8cc63f200b3121db.html
# [325] https://www.pittsburghpa.gov/Recreation-Events/Events/Holidays-At-City-County-Building -> aacdc35f74cf5bd8.html
# [326] https://www.pittsburghpa.gov/Safety/Alerts/Public-Safety-Press-Releases -> 9503d9b40355e25c.html
# [327] https://www.pittsburghpa.gov/City-Government/Contacts-Information/City-Press-Release-Archive -> bbf7e5358784710c.html
# [328] https://www.pittsburghpa.gov/Business-Development/Geographic-Information-Systems-Mapping-Open-Data/Geographic-Information-System-GIS-Mapping -> 6991459ccb916fd0.html
# [329] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Living-with-Wildlife -> 4a7822dd0509cf04.html
# [330] https://www.pittsburghpa.gov/Resident-Services -> 127329446f089c91.html
# [331] https://engage.pittsburghpa.gov/ -> e3754d01efd0d57e.html
# [332] https://www.pittsburghpa.gov/City-Government/Mayor -> 7a69f8c8c6d1d3b6.html
# [333] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/Rodent-Baiting-Program -> e0202d9fe0bc576e.html
# [334] https://www.pittsburghpa.gov/Recreation-Events/Park-Facilities/Schenley-Skating-Rink -> 68a2982138fe8c85.html
# [335] https://www.pittsburghpa.gov/Business-Development/City-Planning/Neighborhood-Planning -> 5a5e1256dd233a20.html
# [336] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Contact-Form -> ff4872bc4af3e271.html
# [337] https://www.pittsburghpa.gov/Recreation-Events/Parks/Our-Parks -> a23f348e868dbf3b.html
# [338] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office -> 1f72f448b1bf8a5d.html
# [339] https://www.pittsburghpa.gov/Recreation-Events/Pools/Pool-Fees -> f71bfc390750d8fc.html
# [340] https://www.pittsburghpa.gov/Resident-Services/Road-Maintenance/Potholes -> 75dcf07a28b7ac73.html
# [341] https://www.pittsburghpa.gov/City-Government/Mayor/Letters-of-Support-Forms -> 942a2a012ec1ed6f.html
# [342] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Community-Resources -> 9c551ff7ec8e3b45.html
# [343] https://www.pittsburghpa.gov/City-Government/Legal-Services/Office-of-Equal-Protection -> 2d8bb4450bcfd4d8.html
# [344] https://www.pittsburghpa.gov/Safety/Fire/Fire-Permit-Information -> cc31f9591cd43c3f.html
# [345] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Privacy-Practices -> b0ca16d111f8b383.html
# [346] https://www.pittsburghpa.gov/Recreation-Events/Pools/Rules -> 5eb5f9da7a37f32e.html
# [347] https://www.pittsburghpa.gov/Recreation-Events/Events -> 0e9ef196160e2825.html
# [348] https://www.pittsburghpa.gov/Resident-Services/Pets-Animals/Animal-Control -> ed6a8215cab8e417.html
# [349] https://www.pittsburghpa.gov/Safety/Police/Police-Officer-Recruitment -> e82b1d4ee1b05a7d.html
# [350] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Annual-Gingerbread-House-Competition -> ce4d926c123ee24f.html
# [351] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/Building-Codes -> 8666fa7541e04701.html
# [352] https://www.pittsburghpa.gov/Resident-Services/A-Z-Frequently-Visited -> 23c6b0c7f28f3b24.html
# [353] https://www.pittsburghpa.gov/Resident-Services/Tree-Resources/Tree-Planting -> b60a255973e8573a.html
# [354] https://www.pittsburghpa.gov/City-Government/Contacts-Information/City-Channel-Pittsburgh -> 64902d4fb6810b69.html
# [355] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/File-a-Grievance -> fea4cdfd5844a503.html
# [356] https://www.pittsburghpa.gov/Business-Development/Mobility-and-Infrastructure/Current-DOMI-Projects -> f5cafac7a0a4bfbd.html
# [357] https://www.pittsburghpa.gov/Safety/Police/Compliment-an-Officer -> 960716c8fd09c51b.html
# [358] https://www.pittsburghpa.gov/Safety/Office-of-Community-Health-and-Safety/Community-Office-Hours -> 60d34387741f3be0.html
# [359] https://www.pittsburghpa.gov/City-Government/Finance-Budget/Real-Estate -> ec91b0fd6ecaffa4.html
# [360] https://www.pittsburghpa.gov/Safety/Police/Submit-a-Tip -> 33c01a16dd4e8a33.html
# [361] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management/Film-Permits -> 50cf61528d2d26af.html
# [362] https://www.pittsburghpa.gov/Resident-Services/Pets-Animals/Dog-License -> c43f4b38fa3187fe.html
# [363] https://www.pittsburghpa.gov/Resident-Services/311 -> 627e857a7ec91f7d.html
# [364] https://www.pittsburghpa.gov/Business-Development/Geographic-Information-Systems-Mapping-Open-Data/Related-Links-Resources -> a2ad0e4ba11d6f08.html
# [365] https://www.pittsburghpa.gov/City-Government/City-Council/Legislative-Information -> 682a6f131f3ae5c0.html
# [366] https://www.pittsburghpa.gov/Resident-Services/ADA-Disability-Rights/Statutes-Policies -> 90108ee2621d3ea8.html
# [367] https://www.pittsburghpa.gov/Home?oc_lang=en-US -> bb21d3642b7e0be8.html
# [368] https://www.pittsburghpa.gov/Safety/Police/Submit-a-Silent-Complaint -> e15bf9c25db72db1.html
# [369] https://www.pittsburghpa.gov/Business-Development/Digital-Equity-In-Pittsburgh -> 3c0c79e4f922dedc.html
# [370] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Campaign-Finances -> dd8a346bbec1ecf5.html
# [371] https://www.pittsburghpa.gov/Resident-Services/Trash-Recycling/Anti-Litter-and-Illegal-Dumping -> 3674037092464377.html
# [372] https://www.pittsburghpa.gov/Safety/Animal-Care-Control/For-Pet-Owners -> b24cc05aaac0401a.html
# [373] https://www.pittsburghpa.gov/Recreation-Events/Park-Permits/Reserve-Park-Shelter -> c9ce8a32694fdaa8.html
# [374] https://www.pittsburghpa.gov/Business-Development/City-Planning/City-Planning-Meetings -> f3acb8ea7b6b014a.html
# [375] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Special-Events-News -> 90ede584dd6ee233.html
# [376] https://www.pittsburghpa.gov/Safety/Fire/Girls-Firefighter-Camp -> 0fe7fb984b718a61.html
# [377] https://www.pittsburghpa.gov/Safety/Public-Safety/Park-Rangers -> 0e24fe3609f9d7da.html
# [378] https://www.pittsburghpa.gov/News-articles -> 981b1492d404f061.html
# [379] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management/Important-Documents -> dc4365a81fc61022.html
# [380] https://www.pittsburghpa.gov/Recreation-Events/Film-Event-Management/Public-Event-Calendar -> 18d12aab9a3c9a62.html
# [381] https://www.pittsburghpa.gov/Resident-Services/Community-Programming/Pittsburghs-Womens-Suffrage-Centennial -> d5fce0e1bd000230.html
# [382] https://www.pittsburghpa.gov/Safety/Fire/Fire-Safety-Programs -> ed0046e3d08ccf79.html
# [383] https://www.pittsburghpa.gov/City-Government/Mayor/Mayors-Cabinet -> a088647cf1ba9bfd.html
# [384] https://www.pittsburghpa.gov/Resident-Services/Food-Programs/BigBurgh -> fb4359d2522f8111.html
# [385] https://www.pittsburghpa.gov/Business-Development/Permits-Licenses-and-Inspections/OneStopPGH -> 105325aef20a1879.html
# [386] https://www.pittsburghpa.gov/Safety/Fire -> 4e8b089998e17b7c.html
# [387] https://www.pittsburghpa.gov/Business-Development/Small-Business-Resources/Startup-Resources -> 17a20d4fbd3381e3.html
# [388] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Audits-Reports -> 072f276fc7f58f80.html
# [389] https://www.pittsburghpa.gov/Recreation-Events/Park-Facilities/Recreation-Centers -> 2c41194564fdfb8d.html
# [390] https://www.pittsburghpa.gov/City-Government/Legal-Services/Right-to-Know -> 261f879a3d70c851.html
# [391] https://www.pittsburghpa.gov/Resident-Services/Community-Programming -> b0be6ed19526cee2.html
# [392] https://www.pittsburghpa.gov/Business-Development/Public-Works/Architecture-Division -> 76a279bdf7062ce0.html
# [393] https://www.pittsburghpa.gov/Safety/Emergency-Medical-Services/Freedom-House-EMT-Training -> fcd24c369f634c80.html
# [394] https://www.pittsburghpa.gov/Safety/Fire/Annual-Reports -> bdcacfa4494cb4e3.html
# [395] https://www.pittsburghpa.gov/Business-Development/Digital-Equity-In-Pittsburgh/Community-Collaborations -> c4a31476c52d3b50.html
# [396] https://www.pittsburghpa.gov/Business-Development/City-Planning/Projects -> 2c68ffc811a22976.html
# [397] https://www.pittsburghpa.gov/Safety/Alerts/COVID-19-Updates -> 3ac06c9cc745dfc6.html
# [398] https://www.pittsburghpa.gov/Recreation-Events/Special-Events/Independence-Day-Celebration -> dd9af1cac2801fff.html
# [399] https://www.pittsburghpa.gov/Safety/Public-Safety -> 6e90986bd3362b3e.html
# [400] https://www.pittsburghpa.gov/City-Government/Legal-Services/Commission-on-Human-Relations -> d932b5ec7327af38.html
# [401] https://www.pittsburghpa.gov/Resident-Services/Tree-Resources/Request-Tree-Work -> c198a51f4ad45350.html
# [402] https://www.pittsburghpa.gov/City-Government/City-Controllers-Office/Pittsburgh-Watchdog -> 6ba9ef07ed459cff.html
# [403] https://www.pittsburghpa.gov/Business-Development/PGH-Lab/Program-Rules-Regulations -> a4db5ee8989ef122.html
# [404] https://www.pittsburghpa.gov/Business-Development/Zoning/Zoning-FAQ -> 6f2768718c973334.html
# [405] https://www.pittsburghpa.gov/Business-Development/Public-Works/About-Public-Works -> c1f38d15dbcb49b6.html
# [406] https://www.cmu.edu/regional-impact -> 56a43d0b8a8f6377.html
# [407] https://www.cmu.edu/work-that-matters -> 88b3e0ef9b8e65b5.html
# [408] https://www.cmu.edu/business-engagement/ -> 3f1df8f6ce2c947a.html
# [409] https://www.cmu.edu/admission/campus-experience/activities-and-engagement -> 9dc824978abd72aa.html
# [410] https://www.cmu.edu/engage/alumni/ -> 8be96ac542ee9ae2.html
# [411] https://www.cmu.edu/title-ix/ -> c585c0b4fc993829.html
# [412] https://www.cmu.edu/news/stories/archives/2025/august/cmu-celebrates-2025-fulbright-recipients -> cc14e57fe83b334c.html
# [413] https://www.cmu.edu/about/history -> e4a1ffff02086732.html
# [414] https://www.cmu.edu/housing/ -> 334ac409f4ab79ac.html
# [415] https://scholars.cmu.edu/ -> 1bc934b864892250.html
# [416] https://www.cmu.edu/uro/ -> 5238032868e5a1d6.html
# [417] https://www.cmu.edu/research-and-creativity -> 32f4517a7e8c76c2.html
# [418] https://www.cmu.edu/campus-life -> 7887bd4de9b55c96.html
# [419] https://www.cmu.edu/news/stories/archives/2025/may/carnegie-mellon-professor-wins-2025-pulitzer-prize-in-history -> b65060c4e3330c79.html
# [420] https://www.cmu.edu/about -> 35ef9aa0384d071f.html
# [421] https://www.cmu.edu/legal/privacy-notice -> 1a1cfc8abb8936d0.html
# [422] https://www.cmu.edu/visit/ -> 680502a417383d0b.html
# [423] https://www.cmu.edu/faculty-staff -> cd9cac59126218fa.html
# [424] https://www.cmu.edu/about/rankings-and-awards -> 80043fb9b647f726.html
# [425] https://www.cmu.edu/graduate/ -> 4b982570824d0118.html
# [426] https://www.ri.cmu.edu/education/academic-programs/doctoral-robotics-program/ -> aeeeccf3f1534ec6.html
# [427] https://www.cmu.edu/academics/interdisciplinary-programs -> 4437930b82796efb.html
# [428] https://www.cmu.edu/pre-college/ -> a910afc6eb26df72.html
# [429] https://www.cmu.edu/admission/majors-programs -> 87f531f97a9f9971.html
# [430] https://www.cmu.edu/news/stories -> b9a72997f629d692.html
# [431] https://events.cmu.edu/event/12957-family-weekend -> 0ddd85a1c6ac9415.html
# [432] https://www.cmu.edu/hr/resources/workday.html -> 49d03af18378f775.html
# [433] https://www.cmu.edu/legal -> d3e4d114a05b0167.html
# [434] https://www.ri.cmu.edu/robot/terregator/ -> 5e5389ee7983ee73.html
# [435] https://ai.cmu.edu/research-and-policy-impact -> 37e190b3a796ad9e.html
# [436] https://www.cmu.edu/admission/admission -> 95d91f1fabd238af.html
# [437] https://engineering.cmu.edu/education/graduate-studies/programs/ms-aie.html -> 6b95376f83ad2cbe.html
# [438] https://www.cmu.edu/directory-contact -> 3518aee3ca206aa3.html
# [439] https://www.cmu.edu/academics/learning-for-a-lifetime -> 76cb80c914b641f1.html
# [440] https://www.cmu.edu/health-safety -> 218524eb13b46623.html
# [441] https://www.cmu.edu/news/stories/archives/2025/september/carnegie-mellon-named-a-top-20-us-university -> e03badb836e35dc4.html
# [442] https://www.cmu.edu/hub/calendar/ -> f7d9f138c8b9ebd4.html
# [443] https://www.cmu.edu/news/stories/archives/2025/october/the-long-game-years-of-cmu-discoveries-drive-new-parkinsons-treatment -> b5e8cd3b42856678.html
# [444] https://www.ri.cmu.edu/robot/navlab-5/ -> a783aabd48ea9575.html
# [445] https://www.cmu.edu/homepage/practical/2007/fall/victory.shtml -> 0204259ef9a8e6c5.html
# [446] https://www.cmu.edu/oie/ -> 2feb093d3a1734b5.html
# [447] https://www.cmu.edu/hub/ -> 0819badc776d5237.html
# [448] https://www.cmu.edu/student-affairs/ -> 0755a504755b27b7.html
# [449] https://www.cmu.edu/graduate/prospective/ -> 26b45375cb942c0f.html
# [450] https://www.cmu.edu/leadership -> f548628e5cf264ee.html
# [451] https://www.cmu.edu/admission/ -> 1f947b7cc61400c0.html
# [452] https://www.cmu.edu/news/stories/archives/2025/may/cmu-undergraduates-take-on-cancer-research -> 2bf46372ab8cc4ba.html
# [453] https://www.cmu.edu/news/stories/archives/2025/october/carnegie-mellon-university-welcomes-second-cohort-of-rales-fellows -> 5b6a65c150a0327c.html
# [454] https://www.cmu.edu/news/stories/archives/2025/september/peacocks-eating-ice-cream-cmu-philosophers-teaching-ai-to-ask-why -> f19e3a2e116801f4.html
# [455] https://www.cmu.edu/cfa/music/ -> 35686ef2dd2954ff.html
# [456] https://www.cmu.edu/career/outcomes/post-grad-dashboard.html -> 8caa46fe04de69f5.html
# [457] https://www.cmu.edu/online/ -> 280e4ed128062307.html
# [458] https://www.library.cmu.edu/ -> 6b3068572b262c6b.html
# [459] https://www.cmu.edu/current-students -> 843547afd9d6f1d0.html
# [460] https://www.cmu.edu/global -> 3ebc91a510c54e0e.html
# ...
# [617] https://downtownpittsburgh.com/events/event/?id=63775 -> 082b25a8fe9a01d3.html
# [618] https://downtownpittsburgh.com/events/event/?id=63926 -> 0018415528ee67e8.html
# [619] https://downtownpittsburgh.com/events/event/?id=63870 -> d3faea6e8993942f.html
# [620] https://downtownpittsburgh.com/live/downtown-lifestyle/residential-resources/ -> 277c26d0e1cbef65.html
# [621] https://downtownpittsburgh.com/do-business/development-activity/ -> 265150b504a91c41.html
# [622] https://downtownpittsburgh.com/events/event/?id=63925 -> 4cf540e2614aacc0.html
# [623] https://downtownpittsburgh.com/events/event/?id=63839 -> 1f32e518827be97d.html
# [624] https://downtownpittsburgh.com/events/?n=11&d=13&y=2025 -> 1d98c843c5cce749.html
# [625] https://downtownpittsburgh.com/events/event/?id=62551 -> deb012ea7b25f8a9.html
# [626] https://downtownpittsburgh.com/events/event/?id=63895 -> 80305a1d5b64a1eb.html
# [627] https://downtownpittsburgh.com/events/event/?id=63877 -> 0900b7f1c993cebb.html
# [628] https://downtownpittsburgh.com/events/event/?id=63165 -> 5526c90e62590f19.html
# [629] https://downtownpittsburgh.com/events/?n=11&d=7&y=2025 -> ebb60696613f8656.html
# [630] https://downtownpittsburgh.com/events/event/?id=63942 -> 9cf165d4fa50eb6a.html
# [631] http://downtownpittsburgh.com/about-pdp/annual-meetings/ -> 271d055e68b607a3.html
# [632] https://downtownpittsburgh.com/events/event/?id=63801 -> 088dcb211dbcac95.html
# [633] https://downtownpittsburgh.com/events/event/?id=63979 -> c1ce74364e8c6b39.html
# [634] https://downtownpittsburgh.com/get-involved/membership/become-a-member/ -> 98a733cb8b422ce2.html
# [635] https://downtownpittsburgh.com/events/?n=10&d=8&y=2025 -> 5a35456e73034c36.html
# [636] https://downtownpittsburgh.com/events/event/?id=63896 -> 509089329714e053.html
# [637] https://downtownpittsburgh.com/events/event/?id=63532 -> b66f4bc4b99f2d8c.html
# [638] https://downtownpittsburgh.com/events/event/?id=63975 -> ed7702337215ca69.html
# [639] https://downtownpittsburgh.com/events/event/?id=63588 -> e4ef6528dc30e5eb.html
# [640] https://downtownpittsburgh.com/events/event/?id=63968 -> 892912cc644405a9.html
# [641] https://downtownpittsburgh.com/privacy-policy/ -> de9c675e3eb9d07f.html
# [642] https://downtownpittsburgh.com/events/event/?id=63696 -> f9dc99878794ce21.html
# [643] https://downtownpittsburgh.com/do-business/retail-small-business-resources/ -> 5dab9efeb42cc268.html
# [644] https://downtownpittsburgh.com/events/event/?id=63822 -> a6cc08079dbdc458.html
# [645] https://downtownpittsburgh.com/about-pdp/clean-outreach-program/ -> 13e52c4a09853a42.html
# [646] https://downtownpittsburgh.com/events/?n=10&d=30&y=2025 -> e084cb5eeca7e8dd.html
# [647] https://downtownpittsburgh.com/about-pdp/business-improvement-district/ -> 3f240a1d6f7c3083.html
# [648] https://downtownpittsburgh.com/events/event/?id=63908 -> ec82729e6c1975e8.html
# [649] https://downtownpittsburgh.com/category/news/ -> 1e2f91a81c2e9975.html
# [650] https://downtownpittsburgh.com/events/event/?id=62504 -> fd6e080a4bdcff04.html
# [651] https://downtownpittsburgh.com/events/?n=11&d=24&y=2025 -> 2a88d34cad64f94e.html
# [652] https://downtownpittsburgh.com/events/?n=10&d=20&y=2025 -> b6236da4c7f8c4fc.html
# [653] https://downtownpittsburgh.com/get-involved/vendor-opportunities/ -> 85515f24f0a281a1.html
# [654] https://downtownpittsburgh.com/events/event/?id=62505 -> 9e32597b00c7108f.html
# [655] https://downtownpittsburgh.com/events/event/?id=63958 -> 5d10f7df42492f26.html
# [656] https://downtownpittsburgh.com/events/?n=9&d=29&y=2025 -> b5f2f1d8008e1473.html
# [657] https://downtownpittsburgh.com/events/?n=11&d=12&y=2025 -> c9a91cf868d83915.html
# [658] https://downtownpittsburgh.com/events/?n=10&d=16&y=2025 -> 40a09cfe73740681.html
# [659] https://downtownpittsburgh.com/events/?n=10&d=23&y=2025 -> 9b3bf96cbc8d8a40.html
# [660] https://downtownpittsburgh.com/events/?n=12&d=1&y=2025 -> 356282a899e1a312.html
# [661] https://downtownpittsburgh.com/events/?n=10&d=2&y=2025 -> 471af101b645b4f2.html
# [662] https://downtownpittsburgh.com/events/?n=10&d=22&y=2025 -> 4ed7e1b6f8c19b8b.html
# [663] https://downtownpittsburgh.com/directory/?TYPE=1&CID=8 -> 236ad58cde2f0bfc.html
# [664] https://downtownpittsburgh.com/live/downtown-lifestyle/ -> e58c36cafdd1b95c.html
# [665] https://downtownpittsburgh.com/events/?n=11&d=22&y=2025 -> a00e57b4274b32bd.html
# [666] https://downtownpittsburgh.com/programs-activities/ -> 7bd9a4f62f5b1d1f.html
# [667] https://downtownpittsburgh.com/events/event/?id=63766 -> 5ee05a9560bfb884.html
# [668] https://downtownpittsburgh.com/events/event/?id=63873 -> 77faab97b84b02a9.html
# [669] https://downtownpittsburgh.com/annual-meetings/ -> 084661af5a7d03f1.html
# [670] https://downtownpittsburgh.com/directory/?TYPE=1&CID=13 -> 88d9a196f7b8e81d.html
# [671] https://downtownpittsburgh.com/events/?n=9&d=28&y=2025 -> 0f485514f2641334.html
# [672] https://downtownpittsburgh.com/events/event/?id=63915 -> 30c31d685411944d.html
# [673] https://downtownpittsburgh.com/events/event/?id=63947 -> dd32604fc309c332.html
# [674] https://downtownpittsburgh.com/events/event/?id=62691 -> 81f68c63087dc553.html
# [675] https://downtownpittsburgh.com/events/event/?id=63784 -> 478aa599055df92c.html
# [676] https://downtownpittsburgh.com/events/?n=11&d=11&y=2025 -> 051b27677f48fb60.html
# [677] https://downtownpittsburgh.com/about-pdp/publications/ -> 4720c7df9ef8bc0a.html
# [678] https://downtownpittsburgh.com/research/ -> 503719d9b531207e.html
# [679] https://downtownpittsburgh.com/events/event/?id=63772 -> ae9d4cb8d56d28fa.html
# [680] https://downtownpittsburgh.com/directory/?TYPE=1&CID=16 -> 73e1a4aafbae76e8.html
# [681] https://downtownpittsburgh.com/events/?n=10&d=13&y=2025 -> d3acab416c1f58a7.html
# [682] https://downtownpittsburgh.com/directory/?TYPE=1&CID=5 -> a505598e823db71f.html
# [683] https://downtownpittsburgh.com/events/event/?id=63906 -> 1fc1c30cd04d02a5.html
# [684] https://downtownpittsburgh.com/events/event/?id=63795 -> f050be03a496f0d5.html
# [685] https://downtownpittsburgh.com/events/event/?id=63891 -> 03b5a703d97c5ff1.html
# [686] https://downtownpittsburgh.com/events/event/?id=62797 -> 9f448c84a024239f.html
# [687] https://downtownpittsburgh.com/events/event/?id=63893 -> e56caf3f49a00e35.html
# [688] https://downtownpittsburgh.com/events/event/?id=63762 -> 7c7f40066b6bfef2.html
# [689] https://downtownpittsburgh.com/events/?n=10&d=12&y=2025 -> 9f8ac332ed3133d1.html
# [690] https://downtownpittsburgh.com/events/event/?id=63875 -> 03ebd53ae52a1e70.html
# [691] https://downtownpittsburgh.com/events/event/?id=63509 -> 0a172e6d7f4eeaa6.html
# [692] https://downtownpittsburgh.com/do-business/retail-small-business-resources/downtown-pittsburgh-retail-snapshot/ -> e1d1a062bee1c97c.html
# [693] https://downtownpittsburgh.com/get-involved/membership/ -> 9560f6cb578aa66b.html
# [694] https://downtownpittsburgh.com/events/event/?id=63982 -> 059205120b458eb4.html
# [695] https://downtownpittsburgh.com/events/event/?id=62502 -> 27d582f10c52b5f7.html
# [696] https://downtownpittsburgh.com/events/event/?id=62715 -> 3b7463b0d7d6d59a.html
# [697] https://downtownpittsburgh.com/events/event/?id=63910 -> 1ae6f18aed0ed6f3.html
# [698] https://downtownpittsburgh.com/events/event/?id=63868 -> fb92a14f0db7720a.html
# [699] https://downtownpittsburgh.com/events/event/?id=63820 -> 367960a7acebf26e.html
# [700] https://downtownpittsburgh.com/directory/?TYPE=1&CID=4 -> b4fb907fcd11e17e.html
# [701] https://downtownpittsburgh.com/events/event/?id=63981 -> 4baeed8ad6ee4cf5.html
# [702] https://downtownpittsburgh.com/visit/getting-here/ -> 20e15b622a5b1f77.html
# [703] https://downtownpittsburgh.com/events/?n=11&d=8&y=2025 -> 0e12ee713ff5124a.html
# [704] https://downtownpittsburgh.com/events/event/?id=63798 -> 58326c3dddd3a381.html
# [705] https://downtownpittsburgh.com/events/event/?id=63808 -> a74f3a0da6f2ed7f.html
# [706] https://downtownpittsburgh.com/events/event/?id=63951 -> 051e4696ff313fdf.html
# [707] https://downtownpittsburgh.com/events/event/?id=63866 -> 7eb4ffd05507eae1.html
# [708] https://downtownpittsburgh.com/events/event/?id=63950 -> c199df8d9308ca56.html
# [709] https://downtownpittsburgh.com/about-pdp/board-of-directors/ -> 7a8f06c5bca05243.html
# [710] https://downtownpittsburgh.com/events/event/?id=63794 -> 6d0bc45d50ad792e.html
# [711] https://downtownpittsburgh.com/about-pdp/staff/ -> 9aa119e59aaf494d.html
# [712] https://downtownpittsburgh.com/events/event/?id=63809 -> ebb274b54cd2578d.html
# [713] https://downtownpittsburgh.com/events/event/?id=63790 -> 2c977753c2fca0f2.html
# [714] https://downtownpittsburgh.com/events/event/?id=63821 -> 5c5cb0607c02af75.html
# [715] https://downtownpittsburgh.com/do-business/paris-to-pittsburgh/ -> 10bcbbec84188d68.html
# [716] https://downtownpittsburgh.com/events/event/?id=63828 -> 988599e3e9dbdfbe.html
# [717] https://downtownpittsburgh.com/events/event/?id=63933 -> 8a8afe89e1585c15.html
# [718] https://downtownpittsburgh.com/events/event/?id=63945 -> 87d0b419b5fc0468.html
# [719] https://downtownpittsburgh.com/events/event/?id=63969 -> 6a9a8a79bcca907b.html
# [720] https://downtownpittsburgh.com/events/event/?id=63962 -> 1f15111d064aa85b.html
# [721] https://downtownpittsburgh.com/events/event/?id=63881 -> d0140902fcbb8abb.html
# [722] https://downtownpittsburgh.com/events/?n=10&d=6&y=2025 -> 744a1a0fa0fdf4f0.html
# [723] https://downtownpittsburgh.com/events/event/?id=63955 -> 5a83ce1cbdcf13f0.html
# [724] https://downtownpittsburgh.com/events/?n=11&y=2025 -> 0baca36c6ade81f7.html
# [725] https://downtownpittsburgh.com/events/event/?id=63924 -> 78e3bdc94685b042.html
# [726] https://downtownpittsburgh.com/events/event/?id=62637 -> 6268ac5d62ea6db8.html
# [727] https://downtownpittsburgh.com/events/event/?id=63920 -> a6203b01c95e8649.html
# [728] https://downtownpittsburgh.com/events/event/?id=62653 -> a9ac932192826fd2.html
# [729] https://downtownpittsburgh.com/events/event/?id=63948 -> 769c2519bf038c70.html
# [730] https://downtownpittsburgh.com/visit/getting-here/driving-directions/ -> fd6193d06bd3ef00.html
# [731] https://downtownpittsburgh.com/events/event/?id=63451 -> 2817820ce9d7b2de.html
# [732] https://downtownpittsburgh.com/events/event/?id=63964 -> a20ce8c7eb7808bb.html
# [733] https://downtownpittsburgh.com/events/?n=11&d=17&y=2025 -> bb1d65147a476bad.html
# [734] https://downtownpittsburgh.com/about-pdp/ -> bf69a02a9344252d.html
# [735] https://downtownpittsburgh.com/events/event/?id=63898 -> f78fb84245b03239.html
# [736] https://downtownpittsburgh.com/events/event/?id=63903 -> ab084b9f96ffb8b6.html
# [737] https://downtownpittsburgh.com/events/?n=10&d=25&y=2025 -> d0e2ac77895ed60c.html
# [738] https://downtownpittsburgh.com/get-involved/membership/membership-directory/ -> 0670c3a87ee56d6c.html
# [739] https://downtownpittsburgh.com/events/event/?id=63876 -> 848398464e4cda18.html
# [740] https://downtownpittsburgh.com/events/?n=10&d=4&y=2025 -> 9c8f29565f135ab7.html
# [741] https://downtownpittsburgh.com/about-pdp/staff/employment/ -> e7dc81f4df3b9e29.html
# [742] https://downtownpittsburgh.com/events/event/?id=63810 -> 5ac22abfb393fdf1.html
# [743] https://downtownpittsburgh.com/events/event/?id=63758 -> 7d6abb6258128093.html
# [744] https://downtownpittsburgh.com/events/event/?id=63613 -> 0c24a56ff406d4f2.html
# [745] https://downtownpittsburgh.com/events/event/?id=62708 -> c2f29fba53e0eef4.html
# [746] https://downtownpittsburgh.com/visit/getting-here/public-transit-passenger-rail/ -> 65a1c2f9fd1fd1e2.html
# [747] https://downtownpittsburgh.com/events/?n=11&d=27&y=2025 -> 5beb58748af3d23a.html
# [748] https://downtownpittsburgh.com/events/?n=11&d=6&y=2025 -> 55040c6875a965a4.html
# [749] https://downtownpittsburgh.com/events/?n=12&d=2&y=2025 -> 42d6249be0823626.html
# [750] https://downtownpittsburgh.com/events/?n=11&d=3&y=2025 -> 10a9a54a498ff36b.html
# [751] https://downtownpittsburgh.com/events/?n=10&d=29&y=2025 -> 7c8e3277aaf1ac05.html
# [752] https://downtownpittsburgh.com/events/event/?id=63836 -> 0f998347f56a8afe.html
# [753] https://downtownpittsburgh.com/events/event/?id=63597 -> 44c2037e87095dbd.html
# [754] https://downtownpittsburgh.com/events/event/?id=63899 -> 099a61998c63d86f.html
# [755] https://downtownpittsburgh.com/directory/?TYPE=1&CID=6 -> dec9fdc815d4517f.html
# [756] https://downtownpittsburgh.com/events/event/?id=63971 -> 96b36974ff328a4d.html
# [757] https://downtownpittsburgh.com/events/event/?id=63913 -> 9e89f4643d367dc8.html
# [758] https://downtownpittsburgh.com/events/event/?id=63807 -> 53379adcf1582adf.html
# [759] https://downtownpittsburgh.com/events/?n=10&d=10&y=2025 -> 54dea92947662430.html
# [760] https://downtownpittsburgh.com/events/event/?id=62503 -> 94c3f8864408cf14.html
# [761] https://downtownpittsburgh.com/events/event/?id=63919 -> 79e514bbd8791fb2.html
# [762] https://downtownpittsburgh.com/events/?n=12&d=5&y=2025 -> cb37f26d62321304.html
# [763] https://downtownpittsburgh.com/events/event/?id=62509 -> ec60fcc2771412e5.html
# [764] https://downtownpittsburgh.com/events/?n=10&d=5&y=2025 -> 249f838202b6ed12.html
# [765] https://downtownpittsburgh.com/events/event/?id=62498 -> 8f0fc7a34b8ce55b.html
# [766] https://downtownpittsburgh.com/events/event/?id=63768 -> 47718cc442913781.html
# [767] https://downtownpittsburgh.com/events/?n=11&d=4&y=2025 -> a0236e27c5442bb7.html
# [768] https://downtownpittsburgh.com/project-pop-up/ -> 52eb7faafb49fc99.html
# [769] https://downtownpittsburgh.com/events/event/?id=63844 -> dbbbd24ea9726380.html
# [770] https://downtownpittsburgh.com/restrooms/ -> 1ebe3d8ac326f2e8.html
# [771] https://downtownpittsburgh.com/events/event/?id=63972 -> 8179285aa16e7e09.html
# [772] https://downtownpittsburgh.com/events/event/?id=63835 -> d9e8df3b3c4ff78f.html
# [773] https://downtownpittsburgh.com/events/event/?id=63704 -> ccfa776cd91cc4ef.html
# [774] https://downtownpittsburgh.com/events/event/?id=62508 -> 2a1400b3ff571e4d.html
# [775] https://downtownpittsburgh.com/events/event/?id=63904 -> ad23146ffd6c82e4.html
# [776] https://downtownpittsburgh.com/events/event/?id=63092 -> c18a746a51960de9.html
# [777] https://downtownpittsburgh.com/terms-of-use/ -> c70a0d90ba89bf91.html
# [778] https://downtownpittsburgh.com/events/?n=11&d=30&y=2025 -> 1699cd4d400e05a5.html
# [779] https://downtownpittsburgh.com/events/event/?id=63864 -> c8b65fa89a6bfcdf.html
# [780] https://downtownpittsburgh.com/events/event/?id=63879 -> 12de7d3b7a5abce0.html
# [781] https://downtownpittsburgh.com/events/event/?id=63838 -> 4029f0277031fe84.html
# [782] https://downtownpittsburgh.com/events/event/?id=63953 -> 139449da0a008be8.html
# [783] https://downtownpittsburgh.com/events/event/?id=63832 -> 19bc1223dc534ed4.html
# [784] https://downtownpittsburgh.com/events/?n=11&d=10&y=2025 -> 461e6bc98002d6d9.html
# [785] https://downtownpittsburgh.com/events/event/?id=63970 -> e7d1aa2131db3bb3.html
# [786] https://downtownpittsburgh.com/events/?n=10&d=21&y=2025 -> 254916ae524fc4bd.html
# [787] https://downtownpittsburgh.com/events/event/?id=63084 -> 5c5a61848e7db354.html
# [788] https://downtownpittsburgh.com/events/event/?id=62721 -> 2a659a2ff501b06e.html
# [789] https://downtownpittsburgh.com/events/event/?id=63878 -> aa62ee002bafa2a6.html
# [790] https://downtownpittsburgh.com/events/event/?id=63965 -> 62dd7298717379a7.html
# [791] https://downtownpittsburgh.com/events/event/?id=63837 -> 7e6face1d0e84d68.html
# [792] https://downtownpittsburgh.com/events/event/?id=63811 -> 0d338b0b8105ce23.html
# [793] https://downtownpittsburgh.com/get-involved/ -> b518e8e0e44bc1a0.html
# [794] https://downtownpittsburgh.com/events/event/?id=63709 -> 30967a1b9a2ae0de.html
# [795] https://downtownpittsburgh.com/events/?n=12&d=3&y=2025 -> 52eec0b4bd0a814a.html
# [796] https://downtownpittsburgh.com/events/?n=11&d=5&y=2025 -> 0f519f380c1546e3.html
# [797] https://downtownpittsburgh.com/events/?n=10&d=18&y=2025 -> 694a822a76144ba3.html
# [798] https://downtownpittsburgh.com/events/event/?id=63125 -> 162bed6503a96cd0.html
# [799] https://downtownpittsburgh.com/events/event/?id=63797 -> 4c2d51a2f16932f5.html
# [800] https://downtownpittsburgh.com/events/event/?id=63760 -> 51fd7d37b3967d2d.html
# Done. Saved 800 files. URL map at /content/rag-pgh/data/raw/url_map.json

# %%
import pdfplumber, re, hashlib
from bs4 import BeautifulSoup
from readability import Document

CORPUS_PATH = root/"data/corpus/documents.jsonl"


def sha1(s): return hashlib.sha1(s.encode("utf-8")).hexdigest()
def norm_text(t): return re.sub(r"\s+", " ", t.lower()).strip()

def html_to_text(html: str):
    try:
        doc = Document(html)
        title = (doc.short_title() or "").strip()
        soup = BeautifulSoup(doc.summary(html_partial=True), "lxml")
        text = soup.get_text("\n", strip=True)
    except Exception:
        soup = BeautifulSoup(html, "lxml")
        title = (soup.title.string if soup.title else "").strip()
        text = soup.get_text("\n", strip=True)
    text = re.sub(r"\n{3,}", "\n\n", text)
    return title, text

def pdf_to_text(path):
    pages = []
    with pdfplumber.open(path) as pdf:
        for p in pdf.pages:
            t = p.extract_text() or ""
            pages.append(t.strip())
    text = "\n\n".join(pages)
    text = re.sub(r"\n{3,}", "\n\n", text)
    title = pathlib.Path(path).name
    return title, text

def extract_corpus():
    url_map = json.loads((RAW_DIR/"url_map.json").read_text()) if (RAW_DIR/"url_map.json").exists() else {}
    seen_hashes = set()
    n_docs = 0

    with open(CORPUS_PATH, "w", encoding="utf-8") as out:
        for p in RAW_DIR.iterdir():
            if not p.is_file(): continue
            if p.name == "url_map.json": continue
            try:
                if p.suffix.lower() == ".pdf":
                    title, text = pdf_to_text(p)
                    source_type = "pdf"
                else:
                    html = p.read_text("utf-8", errors="ignore")
                    title, text = html_to_text(html)
                    source_type = "html"
                if not text or len(text) < 200:
                    continue
                # exact dedup
                h = sha1(norm_text(text))
                if h in seen_hashes:
                    continue
                seen_hashes.add(h)

                row = {
                    "doc_id": p.stem,
                    "url": url_map.get(p.name, ""),
                    "title": title,
                    "source_type": source_type,
                    "char_count": len(text),
                    "text": text
                }
                out.write(json.dumps(row, ensure_ascii=False) + "\n")
                n_docs += 1
            except Exception:
                pass
    print(f"Wrote {n_docs} docs -> {CORPUS_PATH}")

extract_corpus()
# Out:
# Wrote 580 docs -> /content/rag-pgh/data/corpus/documents.jsonl

# %%
import re, uuid, json, hashlib
from pathlib import Path


# project root in Colab
root = Path("/content/rag-pgh")

# input corpus (scraped data) and output chunks
CORPUS_PATH = root / "data/corpus/documents.jsonl"
CHUNKS_PATH = root / "data/corpus/chunks.jsonl"

# Tunables
MAX_CHARS   = 1600      # hard cap per chunk
TARGET_CHARS= 1400      # aim here, try to cut near a boundary
MIN_CHARS   = 300       # avoid tiny chunks; merge/extend if below this
OVERLAP     = 200       # fixed backward overlap in characters
MIN_BOUNDARY_HEADROOM = 200  # try to find a boundary within last 200 chars

# Regexes
SENT_END_RE   = re.compile(r'(?<=[.!?])\s')        # sentence-like boundary
PARA_SPLIT_RE = re.compile(r'\n\s*\n')             # paragraph boundary
LIST_LINE_RE  = re.compile(r'^\s*([-*•]|[0-9]+\.)\s+', re.M)

def _hash_text(s: str) -> str:
    return hashlib.md5(s.encode('utf-8')).hexdigest()

def _find_natural_cut(text: str, start: int, max_chars: int, prefer_window: int) -> int:
    """
    Return an end index in [start+MIN_CHARS, start+max_chars], preferring
    paragraph/list/sentence boundaries close to start+TARGET_CHARS.
    """
    n = len(text)
    hard_end = min(n, start + max_chars)
    target_end = min(n, start + TARGET_CHARS)

    # 1) try paragraph boundary near target
    # search backward from [target_end .. target_end - prefer_window]
    para_back = text.rfind("\n\n", max(start, target_end - prefer_window), target_end)
    if para_back != -1 and para_back - start >= MIN_CHARS:
        return para_back

    # 2) try list-line boundary near target (start of a list item)
    # search forward to end of window for a blank line, then a list bullet
    m = None
    for m in LIST_LINE_RE.finditer(text, start, hard_end):
        if m.start() - start >= MIN_CHARS and m.start() <= target_end:
            # pick the last acceptable match <= target_end
            pass
    if m and m.start() - start >= MIN_CHARS:
        return m.start()

    # 3) try sentence boundary near target (backward search)
    window_start = max(start + MIN_CHARS, target_end - prefer_window)
    window_start = min(window_start, hard_end)
    last_sent = None
    for m in SENT_END_RE.finditer(text, window_start, min(hard_end, target_end + 1)):
        last_sent = m
    if last_sent and (last_sent.end() + start) - start >= MIN_CHARS:
        # m.end() is relative to text, already absolute
        return last_sent.end()

    # 4) fall back: cut at hard_end, but ensure we meet MIN_CHARS if possible
    if hard_end - start >= MIN_CHARS:
        return hard_end

    # 5) if we still can't meet MIN_CHARS (near document end), push to doc end
    return n

def split_into_chunks(text: str,
                      max_chars=MAX_CHARS,
                      overlap=OVERLAP,
                      min_chars=MIN_CHARS,
                      prefer_window=MIN_BOUNDARY_HEADROOM):
    """
    Boundary-aware chunking over original text indices.
    Guarantees: fixed overlap (except first chunk), no 1-char slides, no tiny shards.
    """
    chunks = []
    n = len(text)
    start = 0

    # pre-trim obvious boilerplate-only tails like "last updated: ..." (optional)
    # (No removal here to preserve indices; you can store/update this as metadata instead.)

    while start < n:
        if start > 0:
            # back up by overlap from the previous end (fixed step)
            start = max(0, chunks[-1][1] - overlap)

        end = _find_natural_cut(text, start, max_chars, prefer_window)
        end = max(end, start + min_chars)  # enforce min size if boundary logic failed
        end = min(end, n)

        # If we're stuck (no progress), break to avoid infinite loop
        if chunks and end <= chunks[-1][1]:
            end = min(n, start + max_chars)

        chunk = text[start:end]
        chunk = chunk.strip()

        # Skip empty
        if not chunk:
            # advance safely to avoid 1-char slide
            start = min(n, start + max(min_chars, 1))
            continue

        chunks.append((start, end, chunk))

        if end >= n:
            break

        # Move to next window's nominal start (will be adjusted at top of loop)
        start = end

    # Merge a too-small tail into previous chunk
    if len(chunks) >= 2 and len(chunks[-1][2]) < min_chars:
        prev_start, prev_end, prev_text = chunks[-2]
        last_start, last_end, last_text = chunks[-1]
        merged = (prev_start, last_end, (prev_text + "\n\n" + last_text).strip())
        chunks[-2] = merged
        chunks.pop()

    # De-duplicate (exact) within a doc
    seen = set()
    deduped = []
    for a, b, ch in chunks:
        h = _hash_text(ch)
        if h in seen:
            continue
        seen.add(h)
        deduped.append((a, b, ch))

    return deduped

def build_chunks():
    n_chunks = 0
    with open(CORPUS_PATH, "r", encoding="utf-8") as inp, open(CHUNKS_PATH, "w", encoding="utf-8") as out:
        for line in inp:
            doc = json.loads(line)
            text = doc["text"]
            doc_id = doc["doc_id"]
            url    = doc.get("url", "")
            title  = doc.get("title", "")

            # Split
            parts = split_into_chunks(text)

            # Write
            for (a, b, ch) in parts:
                row = {
                    "chunk_id": str(uuid.uuid4()),
                    "doc_id": doc_id,
                    "url": url,
                    "title": title,
                    "start_char": a,
                    "end_char": b,
                    "text": ch
                }
                out.write(json.dumps(row, ensure_ascii=False) + "\n")
                n_chunks += 1

    print(f"Wrote {n_chunks} chunks -> {CHUNKS_PATH}")

if __name__ == "__main__":
    build_chunks()
# Out:
# Wrote 2445 chunks -> /content/rag-pgh/data/corpus/chunks.jsonl

# %%
import json, statistics, math
from pathlib import Path

CHUNKS_PATH = Path("/content/rag-pgh/data/corpus/chunks.jsonl")

lengths = []
n = 0
examples = []

with open(CHUNKS_PATH, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        row = json.loads(line)
        L = len(row["text"])
        lengths.append(L)
        n += 1
        if i < 3:
            examples.append((row["title"], row["url"], L, row["text"][:300].replace("\n"," ")+"..."))

print(f"Total chunks: {n}")
print("len(text): min/median/mean/p95/max =",
      min(lengths), statistics.median(lengths), round(statistics.mean(lengths),1),
      sorted(lengths)[int(0.95*len(lengths))-1], max(lengths))
print("\nSamples:")
for t,u,L,txt in examples:
    print("-", t, f"({L} chars)")
    print("  ", u)
    print("  ", txt)
# Out:
# Total chunks: 2445
# len(text): min/median/mean/p95/max = 201 1320 1193.5 1600 1872
#
# Samples:
# - Park Maintenance (1600 chars)
#    https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Park-Maintenance
#    Park Maintenance The Department of Public Works is responsible for the daily maintenance and repair of Pittsburgh's park system. Around 100 laborers within our six Parks Divisions care for 163 public parks. We work in cooperation with CitiParks, the Department of Public Works' Forestry Division, and...
# - Park Maintenance (1600 chars)
#    https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Park-Maintenance
#    nd Division 151 Lake Drive Pittsburgh, PA 15206 412-665-3632 Tara Pinnix , Parks Maintenance Manager Jevon Broughton , Foreman Arsenal Park Chadwick Park Dinan Park Duncan Park East Liberty Blvd Strip Enright Park Fifty-Seventh Street Park Fort Pitt Park Friendship Park Garland Park Heth's Park High...
# - Park Maintenance (1600 chars)
#    https://www.pittsburghpa.gov/Recreation-Events/About-Parks/Park-Maintenance
#    ing Hill Park Thomas Park Troy Hill Citizen's Park Washburn Square Park Washington's Landing Park Woods Run Park Young Field Park Emerald Division 1330 Hassler Street Pittsburgh, PA 15204 412-937-3056 Ryan Murray , Parks Maintenance Manager George Movra , Foreman Andrew Joseph Kukuruda Park Banksvil...

# %%
import re, json
from pathlib import Path

IN_CHUNKS  = Path("/content/rag-pgh/data/corpus/chunks.jsonl")
OUT_CLEAN  = Path("/content/rag-pgh/data/corpus/chunks.clean.jsonl")

DROP_URL_PATTERNS = (
    r"/login", r"/signin", r"/sign-in", r"/account", r"/cart", r"/checkout",
    r"/privacy", r"/terms", r"/cookies", r"/language", r"/accessibility"
)
drop_url_rx = re.compile("|".join(DROP_URL_PATTERNS), re.I)

BAD_TITLE_WORDS = re.compile(r"\b(Login|Sign\s*In|Register|Cookie|Privacy|Terms)\b", re.I)

def is_mostly_numeric(text, threshold=0.35):
    if not text: return True
    digits = sum(c.isdigit() for c in text)
    return (digits / max(1, len(text))) > threshold

def low_alpha_ratio(text, threshold=0.55):
    alpha = sum(c.isalpha() for c in text)
    return (alpha / max(1, len(text))) < threshold

def looks_like_nav(text):
    # long bullet/short line lists with little prose
    lines = [ln.strip() for ln in text.splitlines() if ln.strip()]
    if not lines: return True
    short = sum(1 for ln in lines if len(ln) <= 25)
    return len(lines) >= 15 and (short / len(lines)) >= 0.6

kept = 0
skipped = 0
with open(IN_CHUNKS, "r", encoding="utf-8") as inp, open(OUT_CLEAN, "w", encoding="utf-8") as out:
    for line in inp:
        row = json.loads(line)
        url   = row.get("url","") or ""
        title = row.get("title","") or ""
        text  = row.get("text","") or ""

        # URL/title based filters
        if drop_url_rx.search(url) or BAD_TITLE_WORDS.search(title):
            skipped += 1
            continue

        # Content-based filters (conservative)
        if is_mostly_numeric(text) or low_alpha_ratio(text) or looks_like_nav(text):
            skipped += 1
            continue

        out.write(json.dumps(row, ensure_ascii=False) + "\n")
        kept += 1

print(f"Kept {kept} chunks, skipped {skipped}.")
# Out:
# Kept 2072 chunks, skipped 373.

# %%
# !pip -q install dateparser
import json, re, dateparser
from pathlib import Path

IN_PATH  = Path("/content/rag-pgh/data/corpus/chunks.clean.jsonl")
OUT_PATH = Path("/content/rag-pgh/data/corpus/chunks.with_dates.jsonl")

DATE_WINDOW_START = "2025-10-09"
DATE_WINDOW_END   = "2025-12-31"

def to_iso(d):
    try:
        return d.strftime("%Y-%m-%d")
    except:
        return None

def in_window(iso):
    return iso and (DATE_WINDOW_START <= iso <= DATE_WINDOW_END)

date_like_rx = re.compile(
    r"\b(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|"
    r"Jul(?:y)?|Aug(?:ust)?|Sep(?:t(?:ember)?)?|Oct(?:ober)?|Nov(?:ember)?|"
    r"Dec(?:ember)?)\s+\d{1,2},?\s+\d{4}\b"
    r"|"
    r"\b\d{1,2}/\d{1,2}/\d{2,4}\b"
    r"|"
    r"\b\d{4}\b"
, re.I)

kept, flagged = 0, 0
with open(IN_PATH, "r", encoding="utf-8") as inp, open(OUT_PATH, "w", encoding="utf-8") as out:
    for line in inp:
        row = json.loads(line)
        text = row["text"]
        hits = date_like_rx.findall(text)
        iso_dates = []
        for h in hits:
            dt = dateparser.parse(h, settings={"PREFER_DAY_OF_MONTH":"first"})
            if dt:
                iso = to_iso(dt)
                if iso: iso_dates.append(iso)
        row["dates_iso"] = sorted(set(iso_dates))
        row["has_event_in_window"] = any(in_window(d) for d in row["dates_iso"])
        out.write(json.dumps(row, ensure_ascii=False) + "\n")
        kept += 1
        if row["has_event_in_window"]:
            flagged += 1

print(f"Tagged {kept} chunks; {flagged} with dates in {DATE_WINDOW_START}..{DATE_WINDOW_END}.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 23.3 MB/s eta 0:00:00
# Tagged 2072 chunks; 194 with dates in 2025-10-09..2025-12-31.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from pathlib import Path
DRIVE_ROOT = Path('/content/drive/MyDrive/rag-pgh')
DRIVE_ROOT.mkdir(parents=True, exist_ok=True)
DRIVE_ROOT

# %%
# !rsync -av --progress /content/rag-pgh/ /content/drive/MyDrive/rag-pgh/

# %% [markdown]
# RAG system

# %%
#!/usr/bin/env python3
"""
RAG (Retrieval Augmented Generation) System for Pittsburgh/CMU Q&A
"""

import json
import numpy as np
from pathlib import Path
from typing import List, Dict, Any, Tuple
import faiss
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


class RAGSystem:
    def __init__(self, corpus_path: str, model_name: str = "all-MiniLM-L6-v2"):
        """
        Initialize RAG system with document corpus

        Args:
            corpus_path: Path to JSONL file containing document chunks
            model_name: Name of sentence transformer model to use
        """
        self.corpus_path = Path(corpus_path)
        self.model_name = model_name
        self.chunks = []
        self.embeddings = None
        self.index = None
        self.bm25 = None
        self.tfidf = None
        self.tfidf_matrix = None

        # Load sentence transformer model
        print(f"Loading sentence transformer model: {model_name}")
        self.embedder = SentenceTransformer(model_name)

        # Load and process corpus
        self._load_corpus()
        self._build_indices()

    def _load_corpus(self):
        """Load document chunks from JSONL file"""
        print(f"Loading corpus from {self.corpus_path}")
        with open(self.corpus_path, 'r', encoding='utf-8') as f:
            for line in f:
                chunk = json.loads(line.strip())
                self.chunks.append(chunk)
        print(f"Loaded {len(self.chunks)} document chunks")

    def _build_indices(self):
        """Build various search indices"""
        print("Building search indices...")

        # Extract texts for indexing
        texts = [chunk['text'] for chunk in self.chunks]

        # 1. Build FAISS index for dense embeddings
        print("Building FAISS index...")
        self.embeddings = self.embedder.encode(texts, show_progress_bar=True)
        dimension = self.embeddings.shape[1]
        self.index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity
        faiss.normalize_L2(self.embeddings)  # Normalize for cosine similarity
        self.index.add(self.embeddings)

        # 2. Build BM25 index for sparse retrieval
        print("Building BM25 index...")
        tokenized_texts = [self._tokenize(text) for text in texts]
        self.bm25 = BM25Okapi(tokenized_texts)

        # 3. Build TF-IDF index
        print("Building TF-IDF index...")
        self.tfidf = TfidfVectorizer(
            max_features=10000,
            stop_words='english',
            ngram_range=(1, 2),
            min_df=2
        )
        self.tfidf_matrix = self.tfidf.fit_transform(texts)

        print("Indices built successfully!")

    def _tokenize(self, text: str) -> List[str]:
        """Simple tokenization for BM25"""
        return re.findall(r'\b\w+\b', text.lower())

    def retrieve_documents(self, query: str, k: int = 5, method: str = "hybrid") -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query

        Args:
            query: Input question
            k: Number of documents to retrieve
            method: Retrieval method ("dense", "sparse", "tfidf", "hybrid")

        Returns:
            List of relevant document chunks with scores
        """
        if method == "dense":
            return self._dense_retrieval(query, k)
        elif method == "sparse":
            return self._sparse_retrieval(query, k)
        elif method == "tfidf":
            return self._tfidf_retrieval(query, k)
        elif method == "hybrid":
            return self._hybrid_retrieval(query, k)
        else:
            raise ValueError(f"Unknown retrieval method: {method}")

    def _dense_retrieval(self, query: str, k: int) -> List[Dict[str, Any]]:
        """Dense retrieval using sentence transformers"""
        query_embedding = self.embedder.encode([query])
        faiss.normalize_L2(query_embedding)

        scores, indices = self.index.search(query_embedding, k)

        results = []
        for score, idx in zip(scores[0], indices[0]):
            if idx < len(self.chunks):
                chunk = self.chunks[idx].copy()
                chunk['score'] = float(score)
                chunk['method'] = 'dense'
                results.append(chunk)

        return results

    def _sparse_retrieval(self, query: str, k: int) -> List[Dict[str, Any]]:
        """Sparse retrieval using BM25"""
        tokenized_query = self._tokenize(query)
        scores = self.bm25.get_scores(tokenized_query)

        # Get top-k indices
        top_indices = np.argsort(scores)[::-1][:k]

        results = []
        for idx in top_indices:
            if scores[idx] > 0:  # Only include documents with non-zero scores
                chunk = self.chunks[idx].copy()
                chunk['score'] = float(scores[idx])
                chunk['method'] = 'sparse'
                results.append(chunk)

        return results

    def _tfidf_retrieval(self, query: str, k: int) -> List[Dict[str, Any]]:
        """TF-IDF retrieval"""
        query_vector = self.tfidf.transform([query])
        similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Get top-k indices
        top_indices = np.argsort(similarities)[::-1][:k]

        results = []
        for idx in top_indices:
            if similarities[idx] > 0:
                chunk = self.chunks[idx].copy()
                chunk['score'] = float(similarities[idx])
                chunk['method'] = 'tfidf'
                results.append(chunk)

        return results

    def _hybrid_retrieval(self, query: str, k: int) -> List[Dict[str, Any]]:
        """Hybrid retrieval combining dense and sparse methods"""
        # Get more results from each method
        dense_results = self._dense_retrieval(query, k * 2)
        sparse_results = self._sparse_retrieval(query, k * 2)

        # Normalize scores to [0, 1] range
        if dense_results:
            dense_scores = [r['score'] for r in dense_results]
            max_dense = max(dense_scores)
            min_dense = min(dense_scores)
            for r in dense_results:
                r['normalized_score'] = (r['score'] - min_dense) / (max_dense - min_dense) if max_dense > min_dense else 0.5

        if sparse_results:
            sparse_scores = [r['score'] for r in sparse_results]
            max_sparse = max(sparse_scores)
            min_sparse = min(sparse_scores)
            for r in sparse_results:
                r['normalized_score'] = (r['score'] - min_sparse) / (max_sparse - min_sparse) if max_sparse > min_sparse else 0.5

        # Combine results
        combined = {}
        for r in dense_results:
            chunk_id = r['chunk_id']
            if chunk_id not in combined:
                combined[chunk_id] = r.copy()
                combined[chunk_id]['hybrid_score'] = r['normalized_score'] * 0.6  # Weight dense more
            else:
                combined[chunk_id]['hybrid_score'] += r['normalized_score'] * 0.6

        for r in sparse_results:
            chunk_id = r['chunk_id']
            if chunk_id not in combined:
                combined[chunk_id] = r.copy()
                combined[chunk_id]['hybrid_score'] = r['normalized_score'] * 0.4  # Weight sparse less
            else:
                combined[chunk_id]['hybrid_score'] += r['normalized_score'] * 0.4

        # Sort by hybrid score and return top-k
        sorted_results = sorted(combined.values(), key=lambda x: x['hybrid_score'], reverse=True)
        return sorted_results[:k]

    def generate_answer(self, query: str, retrieved_docs: List[Dict[str, Any]],
                       max_context_length: int = 2000) -> str:
        """
        Generate answer using retrieved documents as context

        Args:
            query: Input question
            retrieved_docs: Retrieved document chunks
            max_context_length: Maximum length of context to include

        Returns:
            Generated answer
        """
        # Build context from retrieved documents
        context_parts = []
        current_length = 0

        for doc in retrieved_docs:
            doc_text = f"Source: {doc.get('title', 'Unknown')}\n{doc['text']}\n\n"
            if current_length + len(doc_text) <= max_context_length:
                context_parts.append(doc_text)
                current_length += len(doc_text)
            else:
                break

        context = "".join(context_parts)

        # Simple template-based answer generation
        # In a real system, you would use a proper LLM here
        prompt = f"""Based on the following context, answer the question: {query}

Context:
{context}

Answer:"""

        # For now, return a simple response indicating what was found
        # In practice, you would call an LLM API here
        sources = [doc.get('title', 'Unknown') for doc in retrieved_docs[:3]]
        return f"Based on the retrieved documents from {', '.join(sources)}, I found relevant information about your question. [This is a placeholder - in a real system, an LLM would generate the actual answer here.]"

    def answer_question(self, query: str, k: int = 5, method: str = "hybrid") -> Dict[str, Any]:
        """
        Complete RAG pipeline: retrieve documents and generate answer

        Args:
            query: Input question
            k: Number of documents to retrieve
            method: Retrieval method

        Returns:
            Dictionary containing answer and retrieved documents
        """
        # Retrieve relevant documents
        retrieved_docs = self.retrieve_documents(query, k, method)

        # Generate answer
        answer = self.generate_answer(query, retrieved_docs)

        return {
            'query': query,
            'answer': answer,
            'retrieved_documents': retrieved_docs,
            'num_retrieved': len(retrieved_docs)
        }


def main():
    """Example usage of the RAG system"""
    # Initialize RAG system
    corpus_path = "data/corpus/chunks.jsonl"
    rag = RAGSystem(corpus_path)

    # Example questions
    questions = [
        "When was Carnegie Mellon University founded?",
        "What is the population of Pittsburgh?",
        "What are some popular events in Pittsburgh?",
        "What sports teams are in Pittsburgh?"
    ]

    # Answer questions
    for question in questions:
        print(f"\nQuestion: {question}")
        result = rag.answer_question(question, k=3)
        print(f"Answer: {result['answer']}")
        print(f"Retrieved {result['num_retrieved']} documents")
        print("-" * 50)


if __name__ == "__main__":
    main()
